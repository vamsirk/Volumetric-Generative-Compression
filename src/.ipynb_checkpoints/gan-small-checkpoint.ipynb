# %%
import os
import sys
# import visdom

import numpy as np
import tensorflow as tf
import dataIO as d

from tqdm import *
from utils import *
import pickle
# Out:
# All dependencies not loaded, some functionality may not work

# %%
'''
Global Parameters
'''
n_epochs   = 20000
batch_size = 100
g_lr       = 0.0025
d_lr       = 0.0001
beta       = 0.5
d_thresh   = 0.8
z_size     = 200
leak_value = 0.2
cube_len   = 32
obj_ratio  = 0.5
obj        = 'chair'

# %%
experiment_name = 'gan-small-airplane'

train_sample_directory = './train_sample/' + experiment_name + '/'
model_directory = './models/' + experiment_name + '/'
img_base_directory = './img/'
img_directory = img_base_directory + experiment_name + '/'
pickle_base_directory = './pickle/'
pickle_directory = pickle_base_directory + experiment_name + '/'
is_local = False

if not os.path.exists(img_base_directory):
    os.makedirs(img_base_directory)
if not os.path.exists(pickle_base_directory):
    os.makedirs(img_base_directory)
if not os.path.exists('train_sample'):
    os.makedirs(img_base_directory)
    
weights = {}

# %%
def generator(z, batch_size=batch_size, phase_train=True, reuse=False):

    strides    = [1,2,2,2,1]

    with tf.variable_scope("gen", reuse=reuse):
#         z = tf.reshape(z, (batch_size, 1, 1, 1, z_size))
        g_1 = tf.layers.dense(z, 256*2*2*2, kernel_initializer=tf.random_normal_initializer(stddev=0.02))
        g_1 = tf.reshape(g_1, (-1, 2,2,2,256))
#         g_1 = tf.nn.conv3d_transpose(z, weights['wg1'], (batch_size,4,4,4,512), strides=[1,1,1,1,1], padding="VALID")
        g_1 = tf.contrib.layers.batch_norm(g_1, is_training=phase_train)
        g_1 = tf.nn.relu(g_1)

        g_2 = tf.nn.conv3d_transpose(g_1, weights['wg2'], (batch_size,4,4,4,256), strides=strides, padding="SAME")
        g_2 = tf.contrib.layers.batch_norm(g_2, is_training=phase_train)
        g_2 = tf.nn.relu(g_2)

        g_3 = tf.nn.conv3d_transpose(g_2, weights['wg3'], (batch_size,8,8,8,128), strides=strides, padding="SAME")
        g_3 = tf.contrib.layers.batch_norm(g_3, is_training=phase_train)
        g_3 = tf.nn.relu(g_3)

        g_4 = tf.nn.conv3d_transpose(g_3, weights['wg4'], (batch_size,16,16,16,64), strides=strides, padding="SAME")
        g_4 = tf.contrib.layers.batch_norm(g_4, is_training=phase_train)
        g_4 = tf.nn.relu(g_4)
        
        g_5 = tf.nn.conv3d_transpose(g_4, weights['wg5'], (batch_size,32,32,32,1), strides=strides, padding="SAME")
        g_5 = tf.nn.sigmoid(g_5)
#         g_5 = tf.nn.tanh(g_5)

    print (g_1, 'g1')
    print (g_2, 'g2')
    print (g_3, 'g3')
    print (g_4, 'g4')
    print (g_5, 'g5')
    
    return g_5


def discriminator(inputs, phase_train=True, reuse=False):

    strides    = [1,2,2,2,1]
    with tf.variable_scope("dis", reuse=reuse):
        d_1 = tf.nn.conv3d(inputs, weights['wd1'], strides=strides, padding="SAME")
        d_1 = tf.contrib.layers.batch_norm(d_1, is_training=phase_train)                               
        d_1 = lrelu(d_1, leak_value)

        d_2 = tf.nn.conv3d(d_1, weights['wd2'], strides=strides, padding="SAME") 
        d_2 = tf.contrib.layers.batch_norm(d_2, is_training=phase_train)
        d_2 = lrelu(d_2, leak_value)
        
        d_3 = tf.nn.conv3d(d_2, weights['wd3'], strides=strides, padding="SAME")  
        d_3 = tf.contrib.layers.batch_norm(d_3, is_training=phase_train)
        d_3 = lrelu(d_3, leak_value) 

        d_4 = tf.nn.conv3d(d_3, weights['wd4'], strides=strides, padding="SAME")     
        d_4 = tf.contrib.layers.batch_norm(d_4, is_training=phase_train)
        d_4 = lrelu(d_4)

        d_5 = tf.contrib.layers.flatten(d_4)
        d_5 = tf.layers.dense(d_5, 1, kernel_initializer=tf.random_normal_initializer(stddev=0.02))
#         d_5 = tf.nn.conv3d(d_4, weights['wd5'], strides=[1,1,1,1,1], padding="VALID")     
        d_5_no_sigmoid = d_5
        d_5 = tf.nn.sigmoid(d_5)

    print (d_1, 'd1')
    print (d_2, 'd2')
    print (d_3, 'd3')
    print (d_4, 'd4')
    print (d_5, 'd5')

    return d_5, d_5_no_sigmoid

def initialiseWeights():

    global weights
    xavier_init = tf.contrib.layers.xavier_initializer()

#     weights['wg1'] = tf.get_variable("wg1", shape=[4, 4, 4, 512, 200], initializer=xavier_init)
    weights['wg2'] = tf.get_variable("wg2", shape=[4, 4, 4, 256, 256], initializer=xavier_init)
    weights['wg3'] = tf.get_variable("wg3", shape=[4, 4, 4, 128, 256], initializer=xavier_init)
    weights['wg4'] = tf.get_variable("wg4", shape=[4, 4, 4, 64, 128], initializer=xavier_init)
    weights['wg5'] = tf.get_variable("wg5", shape=[4, 4, 4, 1, 64], initializer=xavier_init)    

    weights['wd1'] = tf.get_variable("wd1", shape=[4, 4, 4, 1, 32], initializer=xavier_init)
    weights['wd2'] = tf.get_variable("wd2", shape=[4, 4, 4, 32, 64], initializer=xavier_init)
    weights['wd3'] = tf.get_variable("wd3", shape=[4, 4, 4, 64, 128], initializer=xavier_init)
    weights['wd4'] = tf.get_variable("wd4", shape=[4, 4, 4, 128, 256], initializer=xavier_init)    
#     weights['wd5'] = tf.get_variable("wd5", shape=[4, 4, 4, 256, 1], initializer=xavier_init)    

    return weights

# %%
def trainGAN(is_dummy=False, checkpoint=None):

    weights =  initialiseWeights()

    z_vector = tf.placeholder(shape=[batch_size,z_size],dtype=tf.float32) 
    x_vector = tf.placeholder(shape=[batch_size,cube_len,cube_len,cube_len,1],dtype=tf.float32) 

    net_g_train = generator(z_vector, phase_train=True, reuse=False) 

    d_output_x, d_no_sigmoid_output_x = discriminator(x_vector, phase_train=True, reuse=False)
    d_output_x = tf.maximum(tf.minimum(d_output_x, 0.99), 0.01)
    summary_d_x_hist = tf.summary.histogram("d_prob_x", d_output_x)

    d_output_z, d_no_sigmoid_output_z = discriminator(net_g_train, phase_train=True, reuse=True)
    d_output_z = tf.maximum(tf.minimum(d_output_z, 0.99), 0.01)
    summary_d_z_hist = tf.summary.histogram("d_prob_z", d_output_z)

    # Compute the discriminator accuracy
    n_p_x = tf.reduce_sum(tf.cast(d_output_x > 0.5, tf.int32))
    n_p_z = tf.reduce_sum(tf.cast(d_output_z < 0.5, tf.int32))
    d_acc = tf.divide(n_p_x + n_p_z, 2 * batch_size)

    # Compute the discriminator and generator loss
    d_loss = -tf.reduce_mean(tf.log(d_output_x) + tf.log(1-d_output_z))
    g_loss = -tf.reduce_mean(tf.log(d_output_z))

#     d_loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=d_no_sigmoid_output_x, labels=tf.ones_like(d_output_x)) + tf.nn.sigmoid_cross_entropy_with_logits(logits=d_no_sigmoid_output_z, labels=tf.zeros_like(d_output_z))
#     g_loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=d_no_sigmoid_output_z, labels=tf.ones_like(d_output_z))
    
#     d_loss = tf.reduce_mean(d_loss)
#     g_loss = tf.reduce_mean(g_loss)

    summary_d_loss = tf.summary.scalar("d_loss", d_loss)
    summary_g_loss = tf.summary.scalar("g_loss", g_loss)
    summary_n_p_z = tf.summary.scalar("n_p_z", n_p_z)
    summary_n_p_x = tf.summary.scalar("n_p_x", n_p_x)
    summary_d_acc = tf.summary.scalar("d_acc", d_acc)

    net_g_test = generator(z_vector, phase_train=False, reuse=True)

    para_g = [var for var in tf.trainable_variables() if any(x in var.name for x in ['wg', 'bg', 'gen'])]
    para_d = [var for var in tf.trainable_variables() if any(x in var.name for x in ['wd', 'bd', 'dis'])]

    # only update the weights for the discriminator network
    optimizer_op_d = tf.train.AdamOptimizer(learning_rate=d_lr,beta1=beta).minimize(d_loss,var_list=para_d)
    # only update the weights for the generator network
    optimizer_op_g = tf.train.AdamOptimizer(learning_rate=g_lr,beta1=beta).minimize(g_loss,var_list=para_g)

    saver = tf.train.Saver() 
#     vis = visdom.Visdom()

    d_losses = []
    g_losses = []
    with tf.Session() as sess:  
      
        sess.run(tf.global_variables_initializer())        
        if checkpoint is not None:
            saver.restore(sess, checkpoint)        

        if is_dummy:
            volumes = np.random.randint(0,2,(batch_size,cube_len,cube_len,cube_len))
            print ('Using Dummy Data')
        else:
            volumes = d.getAll(obj=obj, train=True, is_local=is_local, obj_ratio=obj_ratio, cube_len=32)
            print ('Using ' + obj + ' Data')
        volumes = volumes[...,np.newaxis].astype(np.float)
    
        
        for epoch in range(n_epochs):
            idx = np.random.randint(len(volumes), size=batch_size)
            x = volumes[idx]
            z_sample = np.random.normal(0, 0.33, size=[batch_size, z_size]).astype(np.float32)
            z = np.random.normal(0, 0.33, size=[batch_size, z_size]).astype(np.float32)
            # Update the discriminator and generator
            d_summary_merge = tf.summary.merge([summary_d_loss,
                                                summary_d_x_hist, 
                                                summary_d_z_hist,
                                                summary_n_p_x,
                                                summary_n_p_z,
                                                summary_d_acc])

            summary_d, discriminator_loss = sess.run([d_summary_merge,d_loss],feed_dict={z_vector:z, x_vector:x})
            summary_g, generator_loss = sess.run([summary_g_loss,g_loss],feed_dict={z_vector:z})  
            d_accuracy, n_x, n_z = sess.run([d_acc, n_p_x, n_p_z],feed_dict={z_vector:z, x_vector:x})
            print (n_x, n_z)
            
            d_losses.append(discriminator_loss)
            g_losses.append(generator_loss)

            if d_accuracy < d_thresh:
                sess.run([optimizer_op_d],feed_dict={z_vector:z, x_vector:x})
                print ('Discriminator Training ', "epoch: ",epoch,', d_loss:',discriminator_loss,'g_loss:',generator_loss, "d_acc: ", d_accuracy)

            sess.run([optimizer_op_g],feed_dict={z_vector:z})
            print ('Generator Training ', "epoch: ",epoch,', d_loss:',discriminator_loss,'g_loss:',generator_loss, "d_acc: ", d_accuracy)

            # output generated chairs
            if epoch % 200 == 0:
                g_objects = sess.run(net_g_test,feed_dict={z_vector:z_sample})
                if not os.path.exists(train_sample_directory):
                    os.makedirs(train_sample_directory)
                    
                if not os.path.exists(img_directory):
                    os.makedirs(img_directory)
                    
                if not os.path.exists(pickle_directory):
                    os.makedirs(pickle_directory)
                    
                g_objects.dump(train_sample_directory+'/biasfree_'+str(epoch))
                id_ch = np.random.randint(0, batch_size, 4)
                
                with open(pickle_directory + 'd_loss.pickle', 'wb') as file:
                    pickle.dump(d_losses, file)
                with open(pickle_directory + 'g_loss.pickle', 'wb') as file:
                    pickle.dump(g_losses, file)
                
                for i in range(4):
                    if g_objects[id_ch[i]].max() > 0.5:
                        objects = np.squeeze(g_objects[id_ch[i]]>0.5)
                        d.plotFromVoxels(objects, img_directory+'{}_{}.png'.format(str(epoch), str(i)))
            if epoch % 50 == 10:
                if not os.path.exists(model_directory):
                    os.makedirs(model_directory)      
                saver.save(sess, save_path = model_directory + '/biasfree_' + str(epoch) + '.cptk')


def testGAN(trained_model_path=None, n_batches=40):

    weights = initialiseWeights()

    z_vector = tf.placeholder(shape=[batch_size,z_size],dtype=tf.float32) 
    net_g_test = generator(z_vector, phase_train=True, reuse=True)

#     vis = visdom.Visdom()

    sess = tf.Session()
    saver = tf.train.Saver()
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        saver.restore(sess, trained_model_path) 

        # output generated chairs
        for i in range(n_batches):
            next_sigma = float(raw_input())
            z_sample = np.random.normal(0, next_sigma, size=[batch_size, z_size]).astype(np.float32)
            g_objects = sess.run(net_g_test,feed_dict={z_vector:z_sample})
            id_ch = np.random.randint(0, batch_size, 4)
            for i in range(4):
                print( g_objects[id_ch[i]].max(), g_objects[id_ch[i]].min(), g_objects[id_ch[i]].shape)
                if g_objects[id_ch[i]].max() > 0.5:
                    pass
#                     d.plotVoxelVisdom(np.squeeze(g_objects[id_ch[i]]>0.5), vis, '_'.join(map(str,[i])))

# %%
# if __name__ == '__main__':
#     test = bool(int(sys.argv[1]))
#     if test:
#         path = sys.argv[2]
#         testGAN(trained_model_path=path)
#     else:
#         ckpt = sys.argv[2]
#         if ckpt == '0':
#             trainGAN(is_dummy=False, checkpoint=None)
#         else:
#             trainGAN(is_dummy=False, checkpoint=ckpt)

# %%
trainGAN(is_dummy=False, checkpoint=None)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.5/site-packages/tensorflow/python/ops/nn_impl.py:666: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# Tensor("gen/Relu:0", shape=(100, 2, 2, 2, 256), dtype=float32) g1
# Tensor("gen/Relu_1:0", shape=(100, 4, 4, 4, 256), dtype=float32) g2
# Tensor("gen/Relu_2:0", shape=(100, 8, 8, 8, 128), dtype=float32) g3
# Tensor("gen/Relu_3:0", shape=(100, 16, 16, 16, 64), dtype=float32) g4
# Tensor("gen/Sigmoid:0", shape=(100, 32, 32, 32, 1), dtype=float32) g5
# Tensor("dis/Maximum:0", shape=(100, 16, 16, 16, 32), dtype=float32) d1
# Tensor("dis/Maximum_1:0", shape=(100, 8, 8, 8, 64), dtype=float32) d2
# Tensor("dis/Maximum_2:0", shape=(100, 4, 4, 4, 128), dtype=float32) d3
# Tensor("dis/Maximum_3:0", shape=(100, 2, 2, 2, 256), dtype=float32) d4
# Tensor("dis/Sigmoid:0", shape=(100, 1), dtype=float32) d5
# Tensor("dis_1/Maximum:0", shape=(100, 16, 16, 16, 32), dtype=float32) d1
# Tensor("dis_1/Maximum_1:0", shape=(100, 8, 8, 8, 64), dtype=float32) d2
# Tensor("dis_1/Maximum_2:0", shape=(100, 4, 4, 4, 128), dtype=float32) d3
# Tensor("dis_1/Maximum_3:0", shape=(100, 2, 2, 2, 256), dtype=float32) d4
# Tensor("dis_1/Sigmoid:0", shape=(100, 1), dtype=float32) d5
# Tensor("gen_1/Relu:0", shape=(100, 2, 2, 2, 256), dtype=float32) g1
# Tensor("gen_1/Relu_1:0", shape=(100, 4, 4, 4, 256), dtype=float32) g2
# Tensor("gen_1/Relu_2:0", shape=(100, 8, 8, 8, 128), dtype=float32) g3
# Tensor("gen_1/Relu_3:0", shape=(100, 16, 16, 16, 64), dtype=float32) g4
# Tensor("gen_1/Sigmoid:0", shape=(100, 32, 32, 32, 1), dtype=float32) g5
# Using chair Data
# 74 12
# Discriminator Training  epoch:  0 , d_loss: 1.5709 g_loss: 0.492536 d_acc:  0.43
# Generator Training  epoch:  0 , d_loss: 1.5709 g_loss: 0.492536 d_acc:  0.43
# 97 0
# Discriminator Training  epoch:  1 , d_loss: 3.09886 g_loss: 0.0648206 d_acc:  0.485
# Generator Training  epoch:  1 , d_loss: 3.09886 g_loss: 0.0648206 d_acc:  0.485
# 95 0
# Discriminator Training  epoch:  2 , d_loss: 1.66314 g_loss: 0.300235 d_acc:  0.475
# Generator Training  epoch:  2 , d_loss: 1.66314 g_loss: 0.300235 d_acc:  0.475
# 86 100
# Generator Training  epoch:  3 , d_loss: 0.426306 g_loss: 3.96265 d_acc:  0.93
# 92 0
# Discriminator Training  epoch:  4 , d_loss: 3.30189 g_loss: 0.0570847 d_acc:  0.46
# Generator Training  epoch:  4 , d_loss: 3.30189 g_loss: 0.0570847 d_acc:  0.46
# 87 0
# Discriminator Training  epoch:  5 , d_loss: 3.59183 g_loss: 0.0449031 d_acc:  0.435
# Generator Training  epoch:  5 , d_loss: 3.59183 g_loss: 0.0449031 d_acc:  0.435
# 77 0
# Discriminator Training  epoch:  6 , d_loss: 4.11142 g_loss: 0.0288842 d_acc:  0.385
# Generator Training  epoch:  6 , d_loss: 4.11142 g_loss: 0.0288842 d_acc:  0.385
# 86 0
# Discriminator Training  epoch:  7 , d_loss: 4.23702 g_loss: 0.0243093 d_acc:  0.43
# Generator Training  epoch:  7 , d_loss: 4.23702 g_loss: 0.0243093 d_acc:  0.43
# 92 0
# Discriminator Training  epoch:  8 , d_loss: 4.68185 g_loss: 0.0144099 d_acc:  0.46
# Generator Training  epoch:  8 , d_loss: 4.68185 g_loss: 0.0144099 d_acc:  0.46
# 85 0
# Discriminator Training  epoch:  9 , d_loss: 4.8972 g_loss: 0.0111786 d_acc:  0.425
# Generator Training  epoch:  9 , d_loss: 4.8972 g_loss: 0.0111786 d_acc:  0.425
# 96 0
# Discriminator Training  epoch:  10 , d_loss: 4.70007 g_loss: 0.0118528 d_acc:  0.48
# Generator Training  epoch:  10 , d_loss: 4.70007 g_loss: 0.0118528 d_acc:  0.48
# 99 0
# Discriminator Training  epoch:  11 , d_loss: 4.50325 g_loss: 0.0150472 d_acc:  0.495
# Generator Training  epoch:  11 , d_loss: 4.50325 g_loss: 0.0150472 d_acc:  0.495
# 97 0
# Discriminator Training  epoch:  12 , d_loss: 4.79578 g_loss: 0.0105302 d_acc:  0.485
# Generator Training  epoch:  12 , d_loss: 4.79578 g_loss: 0.0105302 d_acc:  0.485
# 98 0
# Discriminator Training  epoch:  13 , d_loss: 4.78468 g_loss: 0.010172 d_acc:  0.49
# Generator Training  epoch:  13 , d_loss: 4.78468 g_loss: 0.010172 d_acc:  0.49
# 100 0
# Discriminator Training  epoch:  14 , d_loss: 4.66503 g_loss: 0.0106268 d_acc:  0.5
# Generator Training  epoch:  14 , d_loss: 4.66503 g_loss: 0.0106268 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  15 , d_loss: 4.62514 g_loss: 0.0112375 d_acc:  0.5
# Generator Training  epoch:  15 , d_loss: 4.62514 g_loss: 0.0112375 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  16 , d_loss: 4.49797 g_loss: 0.0129272 d_acc:  0.5
# Generator Training  epoch:  16 , d_loss: 4.49797 g_loss: 0.0129272 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  17 , d_loss: 4.70376 g_loss: 0.0105816 d_acc:  0.5
# Generator Training  epoch:  17 , d_loss: 4.70376 g_loss: 0.0105816 d_acc:  0.5
# 99 0
# Discriminator Training  epoch:  18 , d_loss: 4.7292 g_loss: 0.0104697 d_acc:  0.495
# Generator Training  epoch:  18 , d_loss: 4.7292 g_loss: 0.0104697 d_acc:  0.495
# 100 0
# Discriminator Training  epoch:  19 , d_loss: 4.66705 g_loss: 0.0106928 d_acc:  0.5
# Generator Training  epoch:  19 , d_loss: 4.66705 g_loss: 0.0106928 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  20 , d_loss: 4.65441 g_loss: 0.0105502 d_acc:  0.5
# Generator Training  epoch:  20 , d_loss: 4.65441 g_loss: 0.0105502 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  21 , d_loss: 4.61261 g_loss: 0.011213 d_acc:  0.5
# Generator Training  epoch:  21 , d_loss: 4.61261 g_loss: 0.011213 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  22 , d_loss: 4.65064 g_loss: 0.0108514 d_acc:  0.5
# Generator Training  epoch:  22 , d_loss: 4.65064 g_loss: 0.0108514 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  23 , d_loss: 4.67351 g_loss: 0.0106136 d_acc:  0.5
# Generator Training  epoch:  23 , d_loss: 4.67351 g_loss: 0.0106136 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  24 , d_loss: 4.68053 g_loss: 0.0101172 d_acc:  0.5
# Generator Training  epoch:  24 , d_loss: 4.68053 g_loss: 0.0101172 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  25 , d_loss: 4.68485 g_loss: 0.0101417 d_acc:  0.5
# Generator Training  epoch:  25 , d_loss: 4.68485 g_loss: 0.0101417 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  26 , d_loss: 4.64056 g_loss: 0.010332 d_acc:  0.5
# Generator Training  epoch:  26 , d_loss: 4.64056 g_loss: 0.010332 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  27 , d_loss: 4.60161 g_loss: 0.0108466 d_acc:  0.5
# Generator Training  epoch:  27 , d_loss: 4.60161 g_loss: 0.0108466 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  28 , d_loss: 4.6483 g_loss: 0.0106275 d_acc:  0.5
# Generator Training  epoch:  28 , d_loss: 4.6483 g_loss: 0.0106275 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  29 , d_loss: 4.69737 g_loss: 0.0101901 d_acc:  0.5
# Generator Training  epoch:  29 , d_loss: 4.69737 g_loss: 0.0101901 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  30 , d_loss: 4.68479 g_loss: 0.0102248 d_acc:  0.5
# Generator Training  epoch:  30 , d_loss: 4.68479 g_loss: 0.0102248 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  31 , d_loss: 4.67065 g_loss: 0.0101821 d_acc:  0.5
# Generator Training  epoch:  31 , d_loss: 4.67065 g_loss: 0.0101821 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  32 , d_loss: 4.63386 g_loss: 0.0106681 d_acc:  0.5
# Generator Training  epoch:  32 , d_loss: 4.63386 g_loss: 0.0106681 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  33 , d_loss: 4.60724 g_loss: 0.0110386 d_acc:  0.5
# Generator Training  epoch:  33 , d_loss: 4.60724 g_loss: 0.0110386 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  34 , d_loss: 4.67468 g_loss: 0.010212 d_acc:  0.5
# Generator Training  epoch:  34 , d_loss: 4.67468 g_loss: 0.010212 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  35 , d_loss: 4.67658 g_loss: 0.0101793 d_acc:  0.5
# Generator Training  epoch:  35 , d_loss: 4.67658 g_loss: 0.0101793 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  36 , d_loss: 4.68196 g_loss: 0.0100503 d_acc:  0.5
# Generator Training  epoch:  36 , d_loss: 4.68196 g_loss: 0.0100503 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  37 , d_loss: 4.65289 g_loss: 0.0100698 d_acc:  0.5
# Generator Training  epoch:  37 , d_loss: 4.65289 g_loss: 0.0100698 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  38 , d_loss: 4.63919 g_loss: 0.0101748 d_acc:  0.5
# Generator Training  epoch:  38 , d_loss: 4.63919 g_loss: 0.0101748 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  39 , d_loss: 4.61703 g_loss: 0.0104315 d_acc:  0.5
# Generator Training  epoch:  39 , d_loss: 4.61703 g_loss: 0.0104315 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  40 , d_loss: 4.52066 g_loss: 0.012367 d_acc:  0.5
# Generator Training  epoch:  40 , d_loss: 4.52066 g_loss: 0.012367 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  41 , d_loss: 4.65501 g_loss: 0.0101198 d_acc:  0.5
# Generator Training  epoch:  41 , d_loss: 4.65501 g_loss: 0.0101198 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  42 , d_loss: 4.61357 g_loss: 0.0106282 d_acc:  0.5
# Generator Training  epoch:  42 , d_loss: 4.61357 g_loss: 0.0106282 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  43 , d_loss: 4.62761 g_loss: 0.0105422 d_acc:  0.5
# Generator Training  epoch:  43 , d_loss: 4.62761 g_loss: 0.0105422 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  44 , d_loss: 4.6358 g_loss: 0.0104621 d_acc:  0.5
# Generator Training  epoch:  44 , d_loss: 4.6358 g_loss: 0.0104621 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  45 , d_loss: 4.64986 g_loss: 0.0102503 d_acc:  0.5
# Generator Training  epoch:  45 , d_loss: 4.64986 g_loss: 0.0102503 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  46 , d_loss: 4.62927 g_loss: 0.0106255 d_acc:  0.5
# Generator Training  epoch:  46 , d_loss: 4.62927 g_loss: 0.0106255 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  47 , d_loss: 4.64855 g_loss: 0.0103135 d_acc:  0.5
# Generator Training  epoch:  47 , d_loss: 4.64855 g_loss: 0.0103135 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  48 , d_loss: 4.63148 g_loss: 0.0104972 d_acc:  0.5
# Generator Training  epoch:  48 , d_loss: 4.63148 g_loss: 0.0104972 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  49 , d_loss: 4.63495 g_loss: 0.0104741 d_acc:  0.5
# Generator Training  epoch:  49 , d_loss: 4.63495 g_loss: 0.0104741 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  50 , d_loss: 4.62684 g_loss: 0.0105774 d_acc:  0.5
# Generator Training  epoch:  50 , d_loss: 4.62684 g_loss: 0.0105774 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  51 , d_loss: 4.65409 g_loss: 0.0105411 d_acc:  0.5
# Generator Training  epoch:  51 , d_loss: 4.65409 g_loss: 0.0105411 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  52 , d_loss: 4.66311 g_loss: 0.0100632 d_acc:  0.5
# Generator Training  epoch:  52 , d_loss: 4.66311 g_loss: 0.0100632 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  53 , d_loss: 4.65221 g_loss: 0.0100901 d_acc:  0.5
# Generator Training  epoch:  53 , d_loss: 4.65221 g_loss: 0.0100901 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  54 , d_loss: 4.64281 g_loss: 0.0100716 d_acc:  0.5
# Generator Training  epoch:  54 , d_loss: 4.64281 g_loss: 0.0100716 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  55 , d_loss: 4.62021 g_loss: 0.0102517 d_acc:  0.5
# Generator Training  epoch:  55 , d_loss: 4.62021 g_loss: 0.0102517 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  56 , d_loss: 4.5866 g_loss: 0.0109618 d_acc:  0.5
# Generator Training  epoch:  56 , d_loss: 4.5866 g_loss: 0.0109618 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  57 , d_loss: 4.60941 g_loss: 0.0105509 d_acc:  0.5
# Generator Training  epoch:  57 , d_loss: 4.60941 g_loss: 0.0105509 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  58 , d_loss: 4.64272 g_loss: 0.0101081 d_acc:  0.5
# Generator Training  epoch:  58 , d_loss: 4.64272 g_loss: 0.0101081 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  59 , d_loss: 4.64894 g_loss: 0.0100503 d_acc:  0.5
# Generator Training  epoch:  59 , d_loss: 4.64894 g_loss: 0.0100503 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  60 , d_loss: 4.63469 g_loss: 0.0102082 d_acc:  0.5
# Generator Training  epoch:  60 , d_loss: 4.63469 g_loss: 0.0102082 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  61 , d_loss: 4.61614 g_loss: 0.0104113 d_acc:  0.5
# Generator Training  epoch:  61 , d_loss: 4.61614 g_loss: 0.0104113 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  62 , d_loss: 4.61689 g_loss: 0.0104785 d_acc:  0.5
# Generator Training  epoch:  62 , d_loss: 4.61689 g_loss: 0.0104785 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  63 , d_loss: 4.62047 g_loss: 0.0102798 d_acc:  0.5
# Generator Training  epoch:  63 , d_loss: 4.62047 g_loss: 0.0102798 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  64 , d_loss: 4.61617 g_loss: 0.0106347 d_acc:  0.5
# Generator Training  epoch:  64 , d_loss: 4.61617 g_loss: 0.0106347 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  65 , d_loss: 4.65488 g_loss: 0.0100903 d_acc:  0.5
# Generator Training  epoch:  65 , d_loss: 4.65488 g_loss: 0.0100903 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  66 , d_loss: 4.65649 g_loss: 0.0100837 d_acc:  0.5
# Generator Training  epoch:  66 , d_loss: 4.65649 g_loss: 0.0100837 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  67 , d_loss: 4.64341 g_loss: 0.0102063 d_acc:  0.5
# Generator Training  epoch:  67 , d_loss: 4.64341 g_loss: 0.0102063 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  68 , d_loss: 4.61958 g_loss: 0.0103399 d_acc:  0.5
# Generator Training  epoch:  68 , d_loss: 4.61958 g_loss: 0.0103399 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  69 , d_loss: 4.62611 g_loss: 0.0103117 d_acc:  0.5
# Generator Training  epoch:  69 , d_loss: 4.62611 g_loss: 0.0103117 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  70 , d_loss: 4.62455 g_loss: 0.0104473 d_acc:  0.5
# Generator Training  epoch:  70 , d_loss: 4.62455 g_loss: 0.0104473 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  71 , d_loss: 4.65442 g_loss: 0.0101014 d_acc:  0.5
# Generator Training  epoch:  71 , d_loss: 4.65442 g_loss: 0.0101014 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  72 , d_loss: 4.64666 g_loss: 0.0101601 d_acc:  0.5
# Generator Training  epoch:  72 , d_loss: 4.64666 g_loss: 0.0101601 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  73 , d_loss: 4.63786 g_loss: 0.0100672 d_acc:  0.5
# Generator Training  epoch:  73 , d_loss: 4.63786 g_loss: 0.0100672 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  74 , d_loss: 4.63374 g_loss: 0.0100823 d_acc:  0.5
# Generator Training  epoch:  74 , d_loss: 4.63374 g_loss: 0.0100823 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  75 , d_loss: 4.63277 g_loss: 0.010068 d_acc:  0.5
# Generator Training  epoch:  75 , d_loss: 4.63277 g_loss: 0.010068 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  76 , d_loss: 4.60806 g_loss: 0.0104019 d_acc:  0.5
# Generator Training  epoch:  76 , d_loss: 4.60806 g_loss: 0.0104019 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  77 , d_loss: 4.62544 g_loss: 0.010183 d_acc:  0.5
# Generator Training  epoch:  77 , d_loss: 4.62544 g_loss: 0.010183 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  78 , d_loss: 4.64161 g_loss: 0.0100503 d_acc:  0.5
# Generator Training  epoch:  78 , d_loss: 4.64161 g_loss: 0.0100503 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  79 , d_loss: 4.63495 g_loss: 0.0101704 d_acc:  0.5
# Generator Training  epoch:  79 , d_loss: 4.63495 g_loss: 0.0101704 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  80 , d_loss: 4.63874 g_loss: 0.01006 d_acc:  0.5
# Generator Training  epoch:  80 , d_loss: 4.63874 g_loss: 0.01006 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  81 , d_loss: 4.63451 g_loss: 0.0100503 d_acc:  0.5
# Generator Training  epoch:  81 , d_loss: 4.63451 g_loss: 0.0100503 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  82 , d_loss: 4.62248 g_loss: 0.0101097 d_acc:  0.5
# Generator Training  epoch:  82 , d_loss: 4.62248 g_loss: 0.0101097 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  83 , d_loss: 4.61196 g_loss: 0.010235 d_acc:  0.5
# Generator Training  epoch:  83 , d_loss: 4.61196 g_loss: 0.010235 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  84 , d_loss: 4.58976 g_loss: 0.010771 d_acc:  0.5
# Generator Training  epoch:  84 , d_loss: 4.58976 g_loss: 0.010771 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  85 , d_loss: 4.62016 g_loss: 0.010212 d_acc:  0.5
# Generator Training  epoch:  85 , d_loss: 4.62016 g_loss: 0.010212 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  86 , d_loss: 4.63516 g_loss: 0.0100679 d_acc:  0.5
# Generator Training  epoch:  86 , d_loss: 4.63516 g_loss: 0.0100679 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  87 , d_loss: 4.62372 g_loss: 0.0102923 d_acc:  0.5
# Generator Training  epoch:  87 , d_loss: 4.62372 g_loss: 0.0102923 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  88 , d_loss: 4.63247 g_loss: 0.0101463 d_acc:  0.5
# Generator Training  epoch:  88 , d_loss: 4.63247 g_loss: 0.0101463 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  89 , d_loss: 4.64138 g_loss: 0.0101606 d_acc:  0.5
# Generator Training  epoch:  89 , d_loss: 4.64138 g_loss: 0.0101606 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  90 , d_loss: 4.60333 g_loss: 0.010606 d_acc:  0.5
# Generator Training  epoch:  90 , d_loss: 4.60333 g_loss: 0.010606 d_acc:  0.5
# 100 0
# Discriminator Training  epoch:  91 , d_loss: 4.54766 g_loss: 0.0120052 d_acc:  0.5
# Generator Training  epoch:  91 , d_loss: 4.54766 g_loss: 0.0120052 d_acc:  0.5
# 99 100
# Generator Training  epoch:  92 , d_loss: 0.230908 g_loss: 2.38413 d_acc:  0.995
# 100 0
# Discriminator Training  epoch:  93 , d_loss: 3.55111 g_loss: 0.0428236 d_acc:  0.5
# Generator Training  epoch:  93 , d_loss: 3.55111 g_loss: 0.0428236 d_acc:  0.5
# 0 100
# Discriminator Training  epoch:  94 , d_loss: 2.37649 g_loss: 4.60517 d_acc:  0.5
# Generator Training  epoch:  94 , d_loss: 2.37649 g_loss: 4.60517 d_acc:  0.5
# 28 100
# Discriminator Training  epoch:  95 , d_loss: 1.24484 g_loss: 4.60517 d_acc:  0.64
# Generator Training  epoch:  95 , d_loss: 1.24484 g_loss: 4.60517 d_acc:  0.64
# 100 36
# Discriminator Training  epoch:  96 , d_loss: 0.855099 g_loss: 0.648666 d_acc:  0.68
# Generator Training  epoch:  96 , d_loss: 0.855099 g_loss: 0.648666 d_acc:  0.68
# 100 0
# Discriminator Training  epoch:  97 , d_loss: 1.43783 g_loss: 0.343888 d_acc:  0.5
# Generator Training  epoch:  97 , d_loss: 1.43783 g_loss: 0.343888 d_acc:  0.5
# 47 100
# Discriminator Training  epoch:  98 , d_loss: 1.03685 g_loss: 3.69534 d_acc:  0.735
# Generator Training  epoch:  98 , d_loss: 1.03685 g_loss: 3.69534 d_acc:  0.735
# 79 99
# Generator Training  epoch:  99 , d_loss: 0.779558 g_loss: 2.50333 d_acc:  0.89
# 75 4
# Discriminator Training  epoch:  100 , d_loss: 1.993 g_loss: 0.398797 d_acc:  0.395
# Generator Training  epoch:  100 , d_loss: 1.993 g_loss: 0.398797 d_acc:  0.395
# 60 39
# Discriminator Training  epoch:  101 , d_loss: 1.4868 g_loss: 0.664463 d_acc:  0.495
# Generator Training  epoch:  101 , d_loss: 1.4868 g_loss: 0.664463 d_acc:  0.495
# 65 95
# Generator Training  epoch:  102 , d_loss: 1.17697 g_loss: 0.929902 d_acc:  0.8
# 69 31
# Discriminator Training  epoch:  103 , d_loss: 2.82185 g_loss: 0.431708 d_acc:  0.5
# Generator Training  epoch:  103 , d_loss: 2.82185 g_loss: 0.431708 d_acc:  0.5
# 74 31
# Discriminator Training  epoch:  104 , d_loss: 2.32738 g_loss: 0.472878 d_acc:  0.525
# Generator Training  epoch:  104 , d_loss: 2.32738 g_loss: 0.472878 d_acc:  0.525
# 44 100
# Discriminator Training  epoch:  105 , d_loss: 1.30691 g_loss: 1.37727 d_acc:  0.72
# Generator Training  epoch:  105 , d_loss: 1.30691 g_loss: 1.37727 d_acc:  0.72
# 80 23
# Discriminator Training  epoch:  106 , d_loss: 2.03201 g_loss: 0.424288 d_acc:  0.515
# Generator Training  epoch:  106 , d_loss: 2.03201 g_loss: 0.424288 d_acc:  0.515
# 65 100
# Generator Training  epoch:  107 , d_loss: 1.12857 g_loss: 1.11435 d_acc:  0.825
# 63 27
# Discriminator Training  epoch:  108 , d_loss: 2.60098 g_loss: 0.429003 d_acc:  0.45
# Generator Training  epoch:  108 , d_loss: 2.60098 g_loss: 0.429003 d_acc:  0.45
# 35 100
# Discriminator Training  epoch:  109 , d_loss: 1.67684 g_loss: 1.0776 d_acc:  0.675
# Generator Training  epoch:  109 , d_loss: 1.67684 g_loss: 1.0776 d_acc:  0.675
# 69 45
# Discriminator Training  epoch:  110 , d_loss: 2.06307 g_loss: 0.621799 d_acc:  0.57
# Generator Training  epoch:  110 , d_loss: 2.06307 g_loss: 0.621799 d_acc:  0.57
# 87 39
# Discriminator Training  epoch:  111 , d_loss: 1.42877 g_loss: 0.624325 d_acc:  0.63
# Generator Training  epoch:  111 , d_loss: 1.42877 g_loss: 0.624325 d_acc:  0.63
# 70 69
# Discriminator Training  epoch:  112 , d_loss: 1.19966 g_loss: 1.00766 d_acc:  0.695
# Generator Training  epoch:  112 , d_loss: 1.19966 g_loss: 1.00766 d_acc:  0.695
# 78 46
# Discriminator Training  epoch:  113 , d_loss: 1.65113 g_loss: 0.617095 d_acc:  0.62
# Generator Training  epoch:  113 , d_loss: 1.65113 g_loss: 0.617095 d_acc:  0.62
# 71 100
# Generator Training  epoch:  114 , d_loss: 1.13926 g_loss: 1.11821 d_acc:  0.855
# 74 32
# Discriminator Training  epoch:  115 , d_loss: 2.00047 g_loss: 0.472039 d_acc:  0.53
# Generator Training  epoch:  115 , d_loss: 2.00047 g_loss: 0.472039 d_acc:  0.53
# 29 76
# Discriminator Training  epoch:  116 , d_loss: 1.56937 g_loss: 1.16625 d_acc:  0.525
# Generator Training  epoch:  116 , d_loss: 1.56937 g_loss: 1.16625 d_acc:  0.525
# 88 40
# Discriminator Training  epoch:  117 , d_loss: 1.35236 g_loss: 0.631096 d_acc:  0.64
# Generator Training  epoch:  117 , d_loss: 1.35236 g_loss: 0.631096 d_acc:  0.64
# 93 64
# Discriminator Training  epoch:  118 , d_loss: 0.990172 g_loss: 0.805049 d_acc:  0.785
# Generator Training  epoch:  118 , d_loss: 0.990172 g_loss: 0.805049 d_acc:  0.785
# 95 47
# Discriminator Training  epoch:  119 , d_loss: 1.02792 g_loss: 0.717641 d_acc:  0.71
# Generator Training  epoch:  119 , d_loss: 1.02792 g_loss: 0.717641 d_acc:  0.71
# 80 43
# Discriminator Training  epoch:  120 , d_loss: 1.18159 g_loss: 0.706613 d_acc:  0.615
# Generator Training  epoch:  120 , d_loss: 1.18159 g_loss: 0.706613 d_acc:  0.615
# 79 98
# Generator Training  epoch:  121 , d_loss: 1.18733 g_loss: 0.741941 d_acc:  0.885
# 70 0
# Discriminator Training  epoch:  122 , d_loss: 1.82654 g_loss: 0.350928 d_acc:  0.35
# Generator Training  epoch:  122 , d_loss: 1.82654 g_loss: 0.350928 d_acc:  0.35
# 38 97
# Discriminator Training  epoch:  123 , d_loss: 1.34223 g_loss: 1.3664 d_acc:  0.675
# Generator Training  epoch:  123 , d_loss: 1.34223 g_loss: 1.3664 d_acc:  0.675
# 68 83
# Discriminator Training  epoch:  124 , d_loss: 1.27398 g_loss: 0.777939 d_acc:  0.755
# Generator Training  epoch:  124 , d_loss: 1.27398 g_loss: 0.777939 d_acc:  0.755
# 70 0
# Discriminator Training  epoch:  125 , d_loss: 1.95438 g_loss: 0.29824 d_acc:  0.35
# Generator Training  epoch:  125 , d_loss: 1.95438 g_loss: 0.29824 d_acc:  0.35
# 30 1
# Discriminator Training  epoch:  126 , d_loss: 2.12976 g_loss: 0.509452 d_acc:  0.155
# Generator Training  epoch:  126 , d_loss: 2.12976 g_loss: 0.509452 d_acc:  0.155
# 11 100
# Discriminator Training  epoch:  127 , d_loss: 1.90725 g_loss: 0.999182 d_acc:  0.555
# Generator Training  epoch:  127 , d_loss: 1.90725 g_loss: 0.999182 d_acc:  0.555
# 27 19
# Discriminator Training  epoch:  128 , d_loss: 1.73252 g_loss: 0.651546 d_acc:  0.23
# Generator Training  epoch:  128 , d_loss: 1.73252 g_loss: 0.651546 d_acc:  0.23
# 60 1
# Discriminator Training  epoch:  129 , d_loss: 1.5661 g_loss: 0.547 d_acc:  0.305
# Generator Training  epoch:  129 , d_loss: 1.5661 g_loss: 0.547 d_acc:  0.305
# 49 64
# Discriminator Training  epoch:  130 , d_loss: 1.40146 g_loss: 0.769859 d_acc:  0.565
# Generator Training  epoch:  130 , d_loss: 1.40146 g_loss: 0.769859 d_acc:  0.565
# 53 27
# Discriminator Training  epoch:  131 , d_loss: 1.4771 g_loss: 0.642823 d_acc:  0.4
# Generator Training  epoch:  131 , d_loss: 1.4771 g_loss: 0.642823 d_acc:  0.4
# 41 19
# Discriminator Training  epoch:  132 , d_loss: 1.60919 g_loss: 0.62513 d_acc:  0.3
# Generator Training  epoch:  132 , d_loss: 1.60919 g_loss: 0.62513 d_acc:  0.3
# 37 94
# Discriminator Training  epoch:  133 , d_loss: 1.41358 g_loss: 0.828175 d_acc:  0.655
# Generator Training  epoch:  133 , d_loss: 1.41358 g_loss: 0.828175 d_acc:  0.655
# 61 72
# Discriminator Training  epoch:  134 , d_loss: 1.37211 g_loss: 0.796581 d_acc:  0.665
# Generator Training  epoch:  134 , d_loss: 1.37211 g_loss: 0.796581 d_acc:  0.665
# 75 2
# Discriminator Training  epoch:  135 , d_loss: 1.52339 g_loss: 0.503143 d_acc:  0.385
# Generator Training  epoch:  135 , d_loss: 1.52339 g_loss: 0.503143 d_acc:  0.385
# 59 100
# Discriminator Training  epoch:  136 , d_loss: 1.326 g_loss: 0.84618 d_acc:  0.795
# Generator Training  epoch:  136 , d_loss: 1.326 g_loss: 0.84618 d_acc:  0.795
# 49 88
# Discriminator Training  epoch:  137 , d_loss: 1.39725 g_loss: 0.83431 d_acc:  0.685
# Generator Training  epoch:  137 , d_loss: 1.39725 g_loss: 0.83431 d_acc:  0.685
# 55 90
# Discriminator Training  epoch:  138 , d_loss: 1.2537 g_loss: 0.883614 d_acc:  0.725
# Generator Training  epoch:  138 , d_loss: 1.2537 g_loss: 0.883614 d_acc:  0.725
# 65 100
# Generator Training  epoch:  139 , d_loss: 0.98748 g_loss: 1.12896 d_acc:  0.825
# 69 1
# Discriminator Training  epoch:  140 , d_loss: 2.09309 g_loss: 0.263613 d_acc:  0.35
# Generator Training  epoch:  140 , d_loss: 2.09309 g_loss: 0.263613 d_acc:  0.35
# 31 100
# Discriminator Training  epoch:  141 , d_loss: 1.2419 g_loss: 1.58661 d_acc:  0.655
# Generator Training  epoch:  141 , d_loss: 1.2419 g_loss: 1.58661 d_acc:  0.655
# 50 100
# Discriminator Training  epoch:  142 , d_loss: 1.09197 g_loss: 1.17489 d_acc:  0.75
# Generator Training  epoch:  142 , d_loss: 1.09197 g_loss: 1.17489 d_acc:  0.75
# 95 10
# Discriminator Training  epoch:  143 , d_loss: 1.16382 g_loss: 0.605219 d_acc:  0.525
# Generator Training  epoch:  143 , d_loss: 1.16382 g_loss: 0.605219 d_acc:  0.525
# 84 100
# Generator Training  epoch:  144 , d_loss: 1.01095 g_loss: 0.887876 d_acc:  0.92
# 86 0
# Discriminator Training  epoch:  145 , d_loss: 2.70759 g_loss: 0.12184 d_acc:  0.43
# Generator Training  epoch:  145 , d_loss: 2.70759 g_loss: 0.12184 d_acc:  0.43
# 15 100
# Discriminator Training  epoch:  146 , d_loss: 1.62682 g_loss: 1.02401 d_acc:  0.575
# Generator Training  epoch:  146 , d_loss: 1.62682 g_loss: 1.02401 d_acc:  0.575
# 23 100
# Discriminator Training  epoch:  147 , d_loss: 1.49739 g_loss: 1.06304 d_acc:  0.615
# Generator Training  epoch:  147 , d_loss: 1.49739 g_loss: 1.06304 d_acc:  0.615
# 67 15
# Discriminator Training  epoch:  148 , d_loss: 1.57299 g_loss: 0.508711 d_acc:  0.41
# Generator Training  epoch:  148 , d_loss: 1.57299 g_loss: 0.508711 d_acc:  0.41
# 80 76
# Discriminator Training  epoch:  149 , d_loss: 1.15536 g_loss: 0.767538 d_acc:  0.78
# Generator Training  epoch:  149 , d_loss: 1.15536 g_loss: 0.767538 d_acc:  0.78
# 71 100
# Generator Training  epoch:  150 , d_loss: 1.21762 g_loss: 0.777275 d_acc:  0.855
# 71 0
# Discriminator Training  epoch:  151 , d_loss: 2.69832 g_loss: 0.161445 d_acc:  0.355
# Generator Training  epoch:  151 , d_loss: 2.69832 g_loss: 0.161445 d_acc:  0.355
# 33 100
# Discriminator Training  epoch:  152 , d_loss: 1.53912 g_loss: 1.01079 d_acc:  0.665
# Generator Training  epoch:  152 , d_loss: 1.53912 g_loss: 1.01079 d_acc:  0.665
# 28 100
# Discriminator Training  epoch:  153 , d_loss: 1.51638 g_loss: 0.85854 d_acc:  0.64
# Generator Training  epoch:  153 , d_loss: 1.51638 g_loss: 0.85854 d_acc:  0.64
# 63 100
# Generator Training  epoch:  154 , d_loss: 1.30107 g_loss: 0.775451 d_acc:  0.815
# 59 0
# Discriminator Training  epoch:  155 , d_loss: 1.90039 g_loss: 0.339147 d_acc:  0.295
# Generator Training  epoch:  155 , d_loss: 1.90039 g_loss: 0.339147 d_acc:  0.295
# 41 100
# Discriminator Training  epoch:  156 , d_loss: 1.11754 g_loss: 1.20779 d_acc:  0.705
# Generator Training  epoch:  156 , d_loss: 1.11754 g_loss: 1.20779 d_acc:  0.705
# 58 100
# Discriminator Training  epoch:  157 , d_loss: 1.00048 g_loss: 1.29118 d_acc:  0.79
# Generator Training  epoch:  157 , d_loss: 1.00048 g_loss: 1.29118 d_acc:  0.79
# 88 34
# Discriminator Training  epoch:  158 , d_loss: 1.15613 g_loss: 0.693014 d_acc:  0.61
# Generator Training  epoch:  158 , d_loss: 1.15613 g_loss: 0.693014 d_acc:  0.61
# 83 31
# Discriminator Training  epoch:  159 , d_loss: 1.18431 g_loss: 0.68602 d_acc:  0.57
# Generator Training  epoch:  159 , d_loss: 1.18431 g_loss: 0.68602 d_acc:  0.57
# 59 100
# Discriminator Training  epoch:  160 , d_loss: 1.26459 g_loss: 0.82592 d_acc:  0.795
# Generator Training  epoch:  160 , d_loss: 1.26459 g_loss: 0.82592 d_acc:  0.795
# 50 15
# Discriminator Training  epoch:  161 , d_loss: 1.48746 g_loss: 0.649818 d_acc:  0.325
# Generator Training  epoch:  161 , d_loss: 1.48746 g_loss: 0.649818 d_acc:  0.325
# 42 100
# Discriminator Training  epoch:  162 , d_loss: 1.38592 g_loss: 0.879235 d_acc:  0.71
# Generator Training  epoch:  162 , d_loss: 1.38592 g_loss: 0.879235 d_acc:  0.71
# 50 100
# Discriminator Training  epoch:  163 , d_loss: 1.33781 g_loss: 0.865117 d_acc:  0.75
# Generator Training  epoch:  163 , d_loss: 1.33781 g_loss: 0.865117 d_acc:  0.75
# 51 100
# Discriminator Training  epoch:  164 , d_loss: 1.21659 g_loss: 0.945026 d_acc:  0.755
# Generator Training  epoch:  164 , d_loss: 1.21659 g_loss: 0.945026 d_acc:  0.755
# 67 98
# Generator Training  epoch:  165 , d_loss: 0.968076 g_loss: 1.0218 d_acc:  0.825
# 71 3
# Discriminator Training  epoch:  166 , d_loss: 1.92242 g_loss: 0.319923 d_acc:  0.37
# Generator Training  epoch:  166 , d_loss: 1.92242 g_loss: 0.319923 d_acc:  0.37
# 68 100
# Generator Training  epoch:  167 , d_loss: 0.878705 g_loss: 1.56064 d_acc:  0.84
# 48 0
# Discriminator Training  epoch:  168 , d_loss: 2.31643 g_loss: 0.260602 d_acc:  0.24
# Generator Training  epoch:  168 , d_loss: 2.31643 g_loss: 0.260602 d_acc:  0.24
# 58 100
# Discriminator Training  epoch:  169 , d_loss: 1.44813 g_loss: 0.996512 d_acc:  0.79
# Generator Training  epoch:  169 , d_loss: 1.44813 g_loss: 0.996512 d_acc:  0.79
# 50 100
# Discriminator Training  epoch:  170 , d_loss: 1.2671 g_loss: 1.05817 d_acc:  0.75
# Generator Training  epoch:  170 , d_loss: 1.2671 g_loss: 1.05817 d_acc:  0.75
# 63 0
# Discriminator Training  epoch:  171 , d_loss: 1.65014 g_loss: 0.445931 d_acc:  0.315
# Generator Training  epoch:  171 , d_loss: 1.65014 g_loss: 0.445931 d_acc:  0.315
# 52 0
# Discriminator Training  epoch:  172 , d_loss: 2.01178 g_loss: 0.340231 d_acc:  0.26
# Generator Training  epoch:  172 , d_loss: 2.01178 g_loss: 0.340231 d_acc:  0.26
# 24 100
# Discriminator Training  epoch:  173 , d_loss: 1.61934 g_loss: 0.802138 d_acc:  0.62
# Generator Training  epoch:  173 , d_loss: 1.61934 g_loss: 0.802138 d_acc:  0.62
# 37 100
# Discriminator Training  epoch:  174 , d_loss: 1.49141 g_loss: 1.26831 d_acc:  0.685
# Generator Training  epoch:  174 , d_loss: 1.49141 g_loss: 1.26831 d_acc:  0.685
# 45 100
# Discriminator Training  epoch:  175 , d_loss: 1.2862 g_loss: 1.28363 d_acc:  0.725
# Generator Training  epoch:  175 , d_loss: 1.2862 g_loss: 1.28363 d_acc:  0.725
# 68 100
# Generator Training  epoch:  176 , d_loss: 0.976529 g_loss: 1.03899 d_acc:  0.84
# 63 2
# Discriminator Training  epoch:  177 , d_loss: 1.61568 g_loss: 0.443737 d_acc:  0.325
# Generator Training  epoch:  177 , d_loss: 1.61568 g_loss: 0.443737 d_acc:  0.325
# 59 100
# Discriminator Training  epoch:  178 , d_loss: 0.86707 g_loss: 1.67028 d_acc:  0.795
# Generator Training  epoch:  178 , d_loss: 0.86707 g_loss: 1.67028 d_acc:  0.795
# 72 100
# Generator Training  epoch:  179 , d_loss: 0.878968 g_loss: 1.14952 d_acc:  0.86
# 70 17
# Discriminator Training  epoch:  180 , d_loss: 1.65426 g_loss: 0.447179 d_acc:  0.435
# Generator Training  epoch:  180 , d_loss: 1.65426 g_loss: 0.447179 d_acc:  0.435
# 71 100
# Generator Training  epoch:  181 , d_loss: 0.881681 g_loss: 1.25318 d_acc:  0.855
# 67 16
# Discriminator Training  epoch:  182 , d_loss: 1.63566 g_loss: 0.47984 d_acc:  0.415
# Generator Training  epoch:  182 , d_loss: 1.63566 g_loss: 0.47984 d_acc:  0.415
# 51 100
# Discriminator Training  epoch:  183 , d_loss: 1.21057 g_loss: 1.06168 d_acc:  0.755
# Generator Training  epoch:  183 , d_loss: 1.21057 g_loss: 1.06168 d_acc:  0.755
# 51 100
# Discriminator Training  epoch:  184 , d_loss: 1.14973 g_loss: 1.14252 d_acc:  0.755
# Generator Training  epoch:  184 , d_loss: 1.14973 g_loss: 1.14252 d_acc:  0.755
# 68 100
# Generator Training  epoch:  185 , d_loss: 1.06406 g_loss: 0.988771 d_acc:  0.84
# 68 1
# Discriminator Training  epoch:  186 , d_loss: 2.04075 g_loss: 0.301964 d_acc:  0.345
# Generator Training  epoch:  186 , d_loss: 2.04075 g_loss: 0.301964 d_acc:  0.345
# 57 100
# Discriminator Training  epoch:  187 , d_loss: 1.16492 g_loss: 1.29998 d_acc:  0.785
# Generator Training  epoch:  187 , d_loss: 1.16492 g_loss: 1.29998 d_acc:  0.785
# 55 100
# Discriminator Training  epoch:  188 , d_loss: 1.31337 g_loss: 0.964654 d_acc:  0.775
# Generator Training  epoch:  188 , d_loss: 1.31337 g_loss: 0.964654 d_acc:  0.775
# 79 48
# Discriminator Training  epoch:  189 , d_loss: 1.11954 g_loss: 0.702755 d_acc:  0.635
# Generator Training  epoch:  189 , d_loss: 1.11954 g_loss: 0.702755 d_acc:  0.635
# 74 100
# Generator Training  epoch:  190 , d_loss: 1.03912 g_loss: 0.983833 d_acc:  0.87
# 76 0
# Discriminator Training  epoch:  191 , d_loss: 1.76171 g_loss: 0.353811 d_acc:  0.38
# Generator Training  epoch:  191 , d_loss: 1.76171 g_loss: 0.353811 d_acc:  0.38
# 54 100
# Discriminator Training  epoch:  192 , d_loss: 0.95765 g_loss: 1.50281 d_acc:  0.77
# Generator Training  epoch:  192 , d_loss: 0.95765 g_loss: 1.50281 d_acc:  0.77
# 57 100
# Discriminator Training  epoch:  193 , d_loss: 0.903718 g_loss: 1.56372 d_acc:  0.785
# Generator Training  epoch:  193 , d_loss: 0.903718 g_loss: 1.56372 d_acc:  0.785
# 75 100
# Generator Training  epoch:  194 , d_loss: 0.903153 g_loss: 1.12492 d_acc:  0.875
# 76 12
# Discriminator Training  epoch:  195 , d_loss: 1.3106 g_loss: 0.612214 d_acc:  0.44
# Generator Training  epoch:  195 , d_loss: 1.3106 g_loss: 0.612214 d_acc:  0.44
# 65 100
# Generator Training  epoch:  196 , d_loss: 1.07316 g_loss: 0.91326 d_acc:  0.825
# 62 0
# Discriminator Training  epoch:  197 , d_loss: 1.55045 g_loss: 0.476532 d_acc:  0.31
# Generator Training  epoch:  197 , d_loss: 1.55045 g_loss: 0.476532 d_acc:  0.31
# 44 100
# Discriminator Training  epoch:  198 , d_loss: 1.13698 g_loss: 1.15579 d_acc:  0.72
# Generator Training  epoch:  198 , d_loss: 1.13698 g_loss: 1.15579 d_acc:  0.72
# 42 100
# Discriminator Training  epoch:  199 , d_loss: 1.06013 g_loss: 1.35044 d_acc:  0.71
# Generator Training  epoch:  199 , d_loss: 1.06013 g_loss: 1.35044 d_acc:  0.71
# 69 100
# Generator Training  epoch:  200 , d_loss: 0.972103 g_loss: 1.05908 d_acc:  0.845
# 77 27
# Discriminator Training  epoch:  201 , d_loss: 1.36924 g_loss: 0.619476 d_acc:  0.52
# Generator Training  epoch:  201 , d_loss: 1.36924 g_loss: 0.619476 d_acc:  0.52
# 79 100
# Generator Training  epoch:  202 , d_loss: 0.987889 g_loss: 1.02831 d_acc:  0.895
# 67 59
# Discriminator Training  epoch:  203 , d_loss: 1.26889 g_loss: 0.732157 d_acc:  0.63
# Generator Training  epoch:  203 , d_loss: 1.26889 g_loss: 0.732157 d_acc:  0.63
# 65 100
# Generator Training  epoch:  204 , d_loss: 0.948673 g_loss: 1.27344 d_acc:  0.825
# 47 100
# Discriminator Training  epoch:  205 , d_loss: 1.25482 g_loss: 0.892277 d_acc:  0.735
# Generator Training  epoch:  205 , d_loss: 1.25482 g_loss: 0.892277 d_acc:  0.735
# 64 100
# Generator Training  epoch:  206 , d_loss: 1.05579 g_loss: 1.00429 d_acc:  0.82
# 67 6
# Discriminator Training  epoch:  207 , d_loss: 1.39518 g_loss: 0.597034 d_acc:  0.365
# Generator Training  epoch:  207 , d_loss: 1.39518 g_loss: 0.597034 d_acc:  0.365
# 52 100
# Discriminator Training  epoch:  208 , d_loss: 1.25414 g_loss: 0.864085 d_acc:  0.76
# Generator Training  epoch:  208 , d_loss: 1.25414 g_loss: 0.864085 d_acc:  0.76
# 43 100
# Discriminator Training  epoch:  209 , d_loss: 1.23388 g_loss: 0.901183 d_acc:  0.715
# Generator Training  epoch:  209 , d_loss: 1.23388 g_loss: 0.901183 d_acc:  0.715
# 81 100
# Generator Training  epoch:  210 , d_loss: 1.12929 g_loss: 0.85328 d_acc:  0.905
# 69 0
# Discriminator Training  epoch:  211 , d_loss: 1.97036 g_loss: 0.310021 d_acc:  0.345
# Generator Training  epoch:  211 , d_loss: 1.97036 g_loss: 0.310021 d_acc:  0.345
# 32 94
# Discriminator Training  epoch:  212 , d_loss: 1.45061 g_loss: 0.798117 d_acc:  0.63
# Generator Training  epoch:  212 , d_loss: 1.45061 g_loss: 0.798117 d_acc:  0.63
# 34 100
# Discriminator Training  epoch:  213 , d_loss: 1.2789 g_loss: 1.07649 d_acc:  0.67
# Generator Training  epoch:  213 , d_loss: 1.2789 g_loss: 1.07649 d_acc:  0.67
# 39 65
# Discriminator Training  epoch:  214 , d_loss: 1.43132 g_loss: 0.839889 d_acc:  0.52
# Generator Training  epoch:  214 , d_loss: 1.43132 g_loss: 0.839889 d_acc:  0.52
# 79 27
# Discriminator Training  epoch:  215 , d_loss: 1.43163 g_loss: 0.576849 d_acc:  0.53
# Generator Training  epoch:  215 , d_loss: 1.43163 g_loss: 0.576849 d_acc:  0.53
# 65 0
# Discriminator Training  epoch:  216 , d_loss: 1.60831 g_loss: 0.474553 d_acc:  0.325
# Generator Training  epoch:  216 , d_loss: 1.60831 g_loss: 0.474553 d_acc:  0.325
# 38 3
# Discriminator Training  epoch:  217 , d_loss: 1.73901 g_loss: 0.526549 d_acc:  0.205
# Generator Training  epoch:  217 , d_loss: 1.73901 g_loss: 0.526549 d_acc:  0.205
# 21 6
# Discriminator Training  epoch:  218 , d_loss: 1.86769 g_loss: 0.577131 d_acc:  0.135
# Generator Training  epoch:  218 , d_loss: 1.86769 g_loss: 0.577131 d_acc:  0.135
# 16 15
# Discriminator Training  epoch:  219 , d_loss: 1.91303 g_loss: 0.641589 d_acc:  0.155
# Generator Training  epoch:  219 , d_loss: 1.91303 g_loss: 0.641589 d_acc:  0.155
# 25 44
# Discriminator Training  epoch:  220 , d_loss: 1.74951 g_loss: 0.699575 d_acc:  0.345
# Generator Training  epoch:  220 , d_loss: 1.74951 g_loss: 0.699575 d_acc:  0.345
# 31 13
# Discriminator Training  epoch:  221 , d_loss: 1.7107 g_loss: 0.628141 d_acc:  0.22
# Generator Training  epoch:  221 , d_loss: 1.7107 g_loss: 0.628141 d_acc:  0.22
# 32 4
# Discriminator Training  epoch:  222 , d_loss: 1.65682 g_loss: 0.578883 d_acc:  0.18
# Generator Training  epoch:  222 , d_loss: 1.65682 g_loss: 0.578883 d_acc:  0.18
# 45 21
# Discriminator Training  epoch:  223 , d_loss: 1.47321 g_loss: 0.648914 d_acc:  0.33
# Generator Training  epoch:  223 , d_loss: 1.47321 g_loss: 0.648914 d_acc:  0.33
# 37 73
# Discriminator Training  epoch:  224 , d_loss: 1.43588 g_loss: 0.718349 d_acc:  0.55
# Generator Training  epoch:  224 , d_loss: 1.43588 g_loss: 0.718349 d_acc:  0.55
# 49 72
# Discriminator Training  epoch:  225 , d_loss: 1.38974 g_loss: 0.747216 d_acc:  0.605
# Generator Training  epoch:  225 , d_loss: 1.38974 g_loss: 0.747216 d_acc:  0.605
# 52 61
# Discriminator Training  epoch:  226 , d_loss: 1.33217 g_loss: 0.731508 d_acc:  0.565
# Generator Training  epoch:  226 , d_loss: 1.33217 g_loss: 0.731508 d_acc:  0.565
# 59 49
# Discriminator Training  epoch:  227 , d_loss: 1.33492 g_loss: 0.709078 d_acc:  0.54
# Generator Training  epoch:  227 , d_loss: 1.33492 g_loss: 0.709078 d_acc:  0.54
# 62 50
# Discriminator Training  epoch:  228 , d_loss: 1.36616 g_loss: 0.688773 d_acc:  0.56
# Generator Training  epoch:  228 , d_loss: 1.36616 g_loss: 0.688773 d_acc:  0.56
# 59 29
# Discriminator Training  epoch:  229 , d_loss: 1.47683 g_loss: 0.598175 d_acc:  0.44
# Generator Training  epoch:  229 , d_loss: 1.47683 g_loss: 0.598175 d_acc:  0.44
# 60 30
# Discriminator Training  epoch:  230 , d_loss: 1.43591 g_loss: 0.619595 d_acc:  0.45
# Generator Training  epoch:  230 , d_loss: 1.43591 g_loss: 0.619595 d_acc:  0.45
# 49 100
# Discriminator Training  epoch:  231 , d_loss: 1.30223 g_loss: 0.817732 d_acc:  0.745
# Generator Training  epoch:  231 , d_loss: 1.30223 g_loss: 0.817732 d_acc:  0.745
# 51 100
# Discriminator Training  epoch:  232 , d_loss: 1.17573 g_loss: 0.934552 d_acc:  0.755
# Generator Training  epoch:  232 , d_loss: 1.17573 g_loss: 0.934552 d_acc:  0.755
# 64 56
# Discriminator Training  epoch:  233 , d_loss: 1.30979 g_loss: 0.707186 d_acc:  0.6
# Generator Training  epoch:  233 , d_loss: 1.30979 g_loss: 0.707186 d_acc:  0.6
# 63 0
# Discriminator Training  epoch:  234 , d_loss: 1.5296 g_loss: 0.501649 d_acc:  0.315
# Generator Training  epoch:  234 , d_loss: 1.5296 g_loss: 0.501649 d_acc:  0.315
# 36 2
# Discriminator Training  epoch:  235 , d_loss: 1.60025 g_loss: 0.600524 d_acc:  0.19
# Generator Training  epoch:  235 , d_loss: 1.60025 g_loss: 0.600524 d_acc:  0.19
# 13 97
# Discriminator Training  epoch:  236 , d_loss: 1.55925 g_loss: 0.763857 d_acc:  0.55
# Generator Training  epoch:  236 , d_loss: 1.55925 g_loss: 0.763857 d_acc:  0.55
# 19 100
# Discriminator Training  epoch:  237 , d_loss: 1.42593 g_loss: 0.817076 d_acc:  0.595
# Generator Training  epoch:  237 , d_loss: 1.42593 g_loss: 0.817076 d_acc:  0.595
# 45 100
# Discriminator Training  epoch:  238 , d_loss: 1.32435 g_loss: 0.83082 d_acc:  0.725
# Generator Training  epoch:  238 , d_loss: 1.32435 g_loss: 0.83082 d_acc:  0.725
# 71 100
# Generator Training  epoch:  239 , d_loss: 1.1892 g_loss: 0.847472 d_acc:  0.855
# 71 15
# Discriminator Training  epoch:  240 , d_loss: 1.39769 g_loss: 0.63569 d_acc:  0.43
# Generator Training  epoch:  240 , d_loss: 1.39769 g_loss: 0.63569 d_acc:  0.43
# 71 70
# Discriminator Training  epoch:  241 , d_loss: 1.26889 g_loss: 0.76055 d_acc:  0.705
# Generator Training  epoch:  241 , d_loss: 1.26889 g_loss: 0.76055 d_acc:  0.705
# 63 84
# Discriminator Training  epoch:  242 , d_loss: 1.25236 g_loss: 0.808323 d_acc:  0.735
# Generator Training  epoch:  242 , d_loss: 1.25236 g_loss: 0.808323 d_acc:  0.735
# 73 51
# Discriminator Training  epoch:  243 , d_loss: 1.22678 g_loss: 0.743634 d_acc:  0.62
# Generator Training  epoch:  243 , d_loss: 1.22678 g_loss: 0.743634 d_acc:  0.62
# 59 69
# Discriminator Training  epoch:  244 , d_loss: 1.3449 g_loss: 0.741838 d_acc:  0.64
# Generator Training  epoch:  244 , d_loss: 1.3449 g_loss: 0.741838 d_acc:  0.64
# 58 73
# Discriminator Training  epoch:  245 , d_loss: 1.35917 g_loss: 0.746002 d_acc:  0.655
# Generator Training  epoch:  245 , d_loss: 1.35917 g_loss: 0.746002 d_acc:  0.655
# 58 44
# Discriminator Training  epoch:  246 , d_loss: 1.3938 g_loss: 0.706867 d_acc:  0.51
# Generator Training  epoch:  246 , d_loss: 1.3938 g_loss: 0.706867 d_acc:  0.51
# 44 62
# Discriminator Training  epoch:  247 , d_loss: 1.48928 g_loss: 0.733553 d_acc:  0.53
# Generator Training  epoch:  247 , d_loss: 1.48928 g_loss: 0.733553 d_acc:  0.53
# 49 83
# Discriminator Training  epoch:  248 , d_loss: 1.39688 g_loss: 0.722254 d_acc:  0.66
# Generator Training  epoch:  248 , d_loss: 1.39688 g_loss: 0.722254 d_acc:  0.66
# 62 52
# Discriminator Training  epoch:  249 , d_loss: 1.33896 g_loss: 0.696492 d_acc:  0.57
# Generator Training  epoch:  249 , d_loss: 1.33896 g_loss: 0.696492 d_acc:  0.57
# 56 41
# Discriminator Training  epoch:  250 , d_loss: 1.47009 g_loss: 0.637022 d_acc:  0.485
# Generator Training  epoch:  250 , d_loss: 1.47009 g_loss: 0.637022 d_acc:  0.485
# 58 45
# Discriminator Training  epoch:  251 , d_loss: 1.46314 g_loss: 0.636789 d_acc:  0.515
# Generator Training  epoch:  251 , d_loss: 1.46314 g_loss: 0.636789 d_acc:  0.515
# 64 75
# Discriminator Training  epoch:  252 , d_loss: 1.27108 g_loss: 0.777801 d_acc:  0.695
# Generator Training  epoch:  252 , d_loss: 1.27108 g_loss: 0.777801 d_acc:  0.695
# 70 94
# Generator Training  epoch:  253 , d_loss: 1.08599 g_loss: 0.90965 d_acc:  0.82
# 74 0
# Discriminator Training  epoch:  254 , d_loss: 1.7853 g_loss: 0.378279 d_acc:  0.37
# Generator Training  epoch:  254 , d_loss: 1.7853 g_loss: 0.378279 d_acc:  0.37
# 51 100
# Discriminator Training  epoch:  255 , d_loss: 1.31353 g_loss: 0.828693 d_acc:  0.755
# Generator Training  epoch:  255 , d_loss: 1.31353 g_loss: 0.828693 d_acc:  0.755
# 58 39
# Discriminator Training  epoch:  256 , d_loss: 1.34065 g_loss: 0.738419 d_acc:  0.485
# Generator Training  epoch:  256 , d_loss: 1.34065 g_loss: 0.738419 d_acc:  0.485
# 58 0
# Discriminator Training  epoch:  257 , d_loss: 1.58316 g_loss: 0.498723 d_acc:  0.29
# Generator Training  epoch:  257 , d_loss: 1.58316 g_loss: 0.498723 d_acc:  0.29
# 44 0
# Discriminator Training  epoch:  258 , d_loss: 1.7174 g_loss: 0.527751 d_acc:  0.22
# Generator Training  epoch:  258 , d_loss: 1.7174 g_loss: 0.527751 d_acc:  0.22
# 35 60
# Discriminator Training  epoch:  259 , d_loss: 1.6713 g_loss: 0.668472 d_acc:  0.475
# Generator Training  epoch:  259 , d_loss: 1.6713 g_loss: 0.668472 d_acc:  0.475
# 25 72
# Discriminator Training  epoch:  260 , d_loss: 1.63049 g_loss: 0.768368 d_acc:  0.485
# Generator Training  epoch:  260 , d_loss: 1.63049 g_loss: 0.768368 d_acc:  0.485
# 22 70
# Discriminator Training  epoch:  261 , d_loss: 1.65212 g_loss: 0.769175 d_acc:  0.46
# Generator Training  epoch:  261 , d_loss: 1.65212 g_loss: 0.769175 d_acc:  0.46
# 32 62
# Discriminator Training  epoch:  262 , d_loss: 1.64752 g_loss: 0.734606 d_acc:  0.47
# Generator Training  epoch:  262 , d_loss: 1.64752 g_loss: 0.734606 d_acc:  0.47
# 50 65
# Discriminator Training  epoch:  263 , d_loss: 1.44204 g_loss: 0.734097 d_acc:  0.575
# Generator Training  epoch:  263 , d_loss: 1.44204 g_loss: 0.734097 d_acc:  0.575
# 51 88
# Discriminator Training  epoch:  264 , d_loss: 1.3885 g_loss: 0.730664 d_acc:  0.695
# Generator Training  epoch:  264 , d_loss: 1.3885 g_loss: 0.730664 d_acc:  0.695
# 47 70
# Discriminator Training  epoch:  265 , d_loss: 1.41371 g_loss: 0.713542 d_acc:  0.585
# Generator Training  epoch:  265 , d_loss: 1.41371 g_loss: 0.713542 d_acc:  0.585
# 48 26
# Discriminator Training  epoch:  266 , d_loss: 1.44262 g_loss: 0.686192 d_acc:  0.37
# Generator Training  epoch:  266 , d_loss: 1.44262 g_loss: 0.686192 d_acc:  0.37
# 46 0
# Discriminator Training  epoch:  267 , d_loss: 1.54513 g_loss: 0.592326 d_acc:  0.23
# Generator Training  epoch:  267 , d_loss: 1.54513 g_loss: 0.592326 d_acc:  0.23
# 58 27
# Discriminator Training  epoch:  268 , d_loss: 1.46144 g_loss: 0.613749 d_acc:  0.425
# Generator Training  epoch:  268 , d_loss: 1.46144 g_loss: 0.613749 d_acc:  0.425
# 53 100
# Discriminator Training  epoch:  269 , d_loss: 1.24726 g_loss: 0.834055 d_acc:  0.765
# Generator Training  epoch:  269 , d_loss: 1.24726 g_loss: 0.834055 d_acc:  0.765
# 56 100
# Discriminator Training  epoch:  270 , d_loss: 1.23586 g_loss: 0.857397 d_acc:  0.78
# Generator Training  epoch:  270 , d_loss: 1.23586 g_loss: 0.857397 d_acc:  0.78
# 67 77
# Discriminator Training  epoch:  271 , d_loss: 1.28417 g_loss: 0.730985 d_acc:  0.72
# Generator Training  epoch:  271 , d_loss: 1.28417 g_loss: 0.730985 d_acc:  0.72
# 69 96
# Generator Training  epoch:  272 , d_loss: 1.22261 g_loss: 0.754622 d_acc:  0.825
# 59 0
# Discriminator Training  epoch:  273 , d_loss: 1.59228 g_loss: 0.500389 d_acc:  0.295
# Generator Training  epoch:  273 , d_loss: 1.59228 g_loss: 0.500389 d_acc:  0.295
# 55 96
# Discriminator Training  epoch:  274 , d_loss: 1.28347 g_loss: 0.819825 d_acc:  0.755
# Generator Training  epoch:  274 , d_loss: 1.28347 g_loss: 0.819825 d_acc:  0.755
# 57 100
# Discriminator Training  epoch:  275 , d_loss: 1.169 g_loss: 0.953543 d_acc:  0.785
# Generator Training  epoch:  275 , d_loss: 1.169 g_loss: 0.953543 d_acc:  0.785
# 68 48
# Discriminator Training  epoch:  276 , d_loss: 1.23511 g_loss: 0.783985 d_acc:  0.58
# Generator Training  epoch:  276 , d_loss: 1.23511 g_loss: 0.783985 d_acc:  0.58
# 72 31
# Discriminator Training  epoch:  277 , d_loss: 1.33222 g_loss: 0.644474 d_acc:  0.515
# Generator Training  epoch:  277 , d_loss: 1.33222 g_loss: 0.644474 d_acc:  0.515
# 63 67
# Discriminator Training  epoch:  278 , d_loss: 1.34214 g_loss: 0.705633 d_acc:  0.65
# Generator Training  epoch:  278 , d_loss: 1.34214 g_loss: 0.705633 d_acc:  0.65
# 60 100
# Generator Training  epoch:  279 , d_loss: 1.20367 g_loss: 0.897309 d_acc:  0.8
# 61 0
# Discriminator Training  epoch:  280 , d_loss: 1.63449 g_loss: 0.480634 d_acc:  0.305
# Generator Training  epoch:  280 , d_loss: 1.63449 g_loss: 0.480634 d_acc:  0.305
# 45 100
# Discriminator Training  epoch:  281 , d_loss: 1.28969 g_loss: 0.892269 d_acc:  0.725
# Generator Training  epoch:  281 , d_loss: 1.28969 g_loss: 0.892269 d_acc:  0.725
# 36 100
# Discriminator Training  epoch:  282 , d_loss: 1.23119 g_loss: 1.04548 d_acc:  0.68
# Generator Training  epoch:  282 , d_loss: 1.23119 g_loss: 1.04548 d_acc:  0.68
# 58 100
# Discriminator Training  epoch:  283 , d_loss: 1.22374 g_loss: 0.855031 d_acc:  0.79
# Generator Training  epoch:  283 , d_loss: 1.22374 g_loss: 0.855031 d_acc:  0.79
# 74 80
# Discriminator Training  epoch:  284 , d_loss: 1.19716 g_loss: 0.77845 d_acc:  0.77
# Generator Training  epoch:  284 , d_loss: 1.19716 g_loss: 0.77845 d_acc:  0.77
# 57 100
# Discriminator Training  epoch:  285 , d_loss: 1.25876 g_loss: 0.81089 d_acc:  0.785
# Generator Training  epoch:  285 , d_loss: 1.25876 g_loss: 0.81089 d_acc:  0.785
# 53 100
# Discriminator Training  epoch:  286 , d_loss: 1.29142 g_loss: 0.832411 d_acc:  0.765
# Generator Training  epoch:  286 , d_loss: 1.29142 g_loss: 0.832411 d_acc:  0.765
# 57 100
# Discriminator Training  epoch:  287 , d_loss: 1.23392 g_loss: 0.808099 d_acc:  0.785
# ...
# 69 100
# Generator Training  epoch:  1304 , d_loss: 1.0431 g_loss: 1.02666 d_acc:  0.845
# 66 40
# Discriminator Training  epoch:  1305 , d_loss: 1.38755 g_loss: 0.676811 d_acc:  0.53
# Generator Training  epoch:  1305 , d_loss: 1.38755 g_loss: 0.676811 d_acc:  0.53
# 53 60
# Discriminator Training  epoch:  1306 , d_loss: 1.40193 g_loss: 0.760366 d_acc:  0.565
# Generator Training  epoch:  1306 , d_loss: 1.40193 g_loss: 0.760366 d_acc:  0.565
# 54 96
# Discriminator Training  epoch:  1307 , d_loss: 1.27763 g_loss: 0.865589 d_acc:  0.75
# Generator Training  epoch:  1307 , d_loss: 1.27763 g_loss: 0.865589 d_acc:  0.75
# 68 88
# Discriminator Training  epoch:  1308 , d_loss: 1.20128 g_loss: 0.827931 d_acc:  0.78
# Generator Training  epoch:  1308 , d_loss: 1.20128 g_loss: 0.827931 d_acc:  0.78
# 71 93
# Generator Training  epoch:  1309 , d_loss: 1.08163 g_loss: 0.918712 d_acc:  0.82
# 66 23
# Discriminator Training  epoch:  1310 , d_loss: 1.4216 g_loss: 0.621432 d_acc:  0.445
# Generator Training  epoch:  1310 , d_loss: 1.4216 g_loss: 0.621432 d_acc:  0.445
# 48 97
# Discriminator Training  epoch:  1311 , d_loss: 1.22439 g_loss: 1.12742 d_acc:  0.725
# Generator Training  epoch:  1311 , d_loss: 1.22439 g_loss: 1.12742 d_acc:  0.725
# 60 93
# Discriminator Training  epoch:  1312 , d_loss: 1.12254 g_loss: 1.01031 d_acc:  0.765
# Generator Training  epoch:  1312 , d_loss: 1.12254 g_loss: 1.01031 d_acc:  0.765
# 76 60
# Discriminator Training  epoch:  1313 , d_loss: 1.21674 g_loss: 0.719085 d_acc:  0.68
# Generator Training  epoch:  1313 , d_loss: 1.21674 g_loss: 0.719085 d_acc:  0.68
# 71 90
# Generator Training  epoch:  1314 , d_loss: 1.09516 g_loss: 0.918706 d_acc:  0.805
# 72 29
# Discriminator Training  epoch:  1315 , d_loss: 1.44295 g_loss: 0.597134 d_acc:  0.505
# Generator Training  epoch:  1315 , d_loss: 1.44295 g_loss: 0.597134 d_acc:  0.505
# 25 100
# Discriminator Training  epoch:  1316 , d_loss: 1.40191 g_loss: 1.11992 d_acc:  0.625
# Generator Training  epoch:  1316 , d_loss: 1.40191 g_loss: 1.11992 d_acc:  0.625
# 66 57
# Discriminator Training  epoch:  1317 , d_loss: 1.29273 g_loss: 0.734028 d_acc:  0.615
# Generator Training  epoch:  1317 , d_loss: 1.29273 g_loss: 0.734028 d_acc:  0.615
# 80 41
# Discriminator Training  epoch:  1318 , d_loss: 1.23125 g_loss: 0.677675 d_acc:  0.605
# Generator Training  epoch:  1318 , d_loss: 1.23125 g_loss: 0.677675 d_acc:  0.605
# 48 97
# Discriminator Training  epoch:  1319 , d_loss: 1.25852 g_loss: 0.944778 d_acc:  0.725
# Generator Training  epoch:  1319 , d_loss: 1.25852 g_loss: 0.944778 d_acc:  0.725
# 58 66
# Discriminator Training  epoch:  1320 , d_loss: 1.27529 g_loss: 0.787734 d_acc:  0.62
# Generator Training  epoch:  1320 , d_loss: 1.27529 g_loss: 0.787734 d_acc:  0.62
# 65 59
# Discriminator Training  epoch:  1321 , d_loss: 1.27661 g_loss: 0.751007 d_acc:  0.62
# Generator Training  epoch:  1321 , d_loss: 1.27661 g_loss: 0.751007 d_acc:  0.62
# 61 87
# Discriminator Training  epoch:  1322 , d_loss: 1.21293 g_loss: 0.907384 d_acc:  0.74
# Generator Training  epoch:  1322 , d_loss: 1.21293 g_loss: 0.907384 d_acc:  0.74
# 76 71
# Discriminator Training  epoch:  1323 , d_loss: 1.14059 g_loss: 0.854219 d_acc:  0.735
# Generator Training  epoch:  1323 , d_loss: 1.14059 g_loss: 0.854219 d_acc:  0.735
# 73 85
# Discriminator Training  epoch:  1324 , d_loss: 1.13502 g_loss: 0.897528 d_acc:  0.79
# Generator Training  epoch:  1324 , d_loss: 1.13502 g_loss: 0.897528 d_acc:  0.79
# 89 84
# Generator Training  epoch:  1325 , d_loss: 1.01745 g_loss: 0.897509 d_acc:  0.865
# 81 59
# Discriminator Training  epoch:  1326 , d_loss: 1.28992 g_loss: 0.716431 d_acc:  0.7
# Generator Training  epoch:  1326 , d_loss: 1.28992 g_loss: 0.716431 d_acc:  0.7
# 69 86
# Discriminator Training  epoch:  1327 , d_loss: 1.15324 g_loss: 0.930207 d_acc:  0.775
# Generator Training  epoch:  1327 , d_loss: 1.15324 g_loss: 0.930207 d_acc:  0.775
# 52 90
# Discriminator Training  epoch:  1328 , d_loss: 1.20124 g_loss: 0.961409 d_acc:  0.71
# Generator Training  epoch:  1328 , d_loss: 1.20124 g_loss: 0.961409 d_acc:  0.71
# 83 49
# Discriminator Training  epoch:  1329 , d_loss: 1.18584 g_loss: 0.729914 d_acc:  0.66
# Generator Training  epoch:  1329 , d_loss: 1.18584 g_loss: 0.729914 d_acc:  0.66
# 89 72
# Generator Training  epoch:  1330 , d_loss: 1.04848 g_loss: 0.849859 d_acc:  0.805
# 67 39
# Discriminator Training  epoch:  1331 , d_loss: 1.44166 g_loss: 0.605155 d_acc:  0.53
# Generator Training  epoch:  1331 , d_loss: 1.44166 g_loss: 0.605155 d_acc:  0.53
# 38 100
# Discriminator Training  epoch:  1332 , d_loss: 1.28045 g_loss: 1.07523 d_acc:  0.69
# Generator Training  epoch:  1332 , d_loss: 1.28045 g_loss: 1.07523 d_acc:  0.69
# 89 80
# Generator Training  epoch:  1333 , d_loss: 1.10782 g_loss: 0.810924 d_acc:  0.845
# 90 32
# Discriminator Training  epoch:  1334 , d_loss: 1.24377 g_loss: 0.636129 d_acc:  0.61
# Generator Training  epoch:  1334 , d_loss: 1.24377 g_loss: 0.636129 d_acc:  0.61
# 64 87
# Discriminator Training  epoch:  1335 , d_loss: 1.19694 g_loss: 0.893897 d_acc:  0.755
# Generator Training  epoch:  1335 , d_loss: 1.19694 g_loss: 0.893897 d_acc:  0.755
# 65 100
# Generator Training  epoch:  1336 , d_loss: 1.14408 g_loss: 0.997308 d_acc:  0.825
# 53 59
# Discriminator Training  epoch:  1337 , d_loss: 1.38122 g_loss: 0.754543 d_acc:  0.56
# Generator Training  epoch:  1337 , d_loss: 1.38122 g_loss: 0.754543 d_acc:  0.56
# 75 89
# Generator Training  epoch:  1338 , d_loss: 1.14525 g_loss: 0.816412 d_acc:  0.82
# 59 12
# Discriminator Training  epoch:  1339 , d_loss: 1.5143 g_loss: 0.57193 d_acc:  0.355
# Generator Training  epoch:  1339 , d_loss: 1.5143 g_loss: 0.57193 d_acc:  0.355
# 25 99
# Discriminator Training  epoch:  1340 , d_loss: 1.38184 g_loss: 1.08657 d_acc:  0.62
# Generator Training  epoch:  1340 , d_loss: 1.38184 g_loss: 1.08657 d_acc:  0.62
# 81 67
# Discriminator Training  epoch:  1341 , d_loss: 1.20382 g_loss: 0.712744 d_acc:  0.74
# Generator Training  epoch:  1341 , d_loss: 1.20382 g_loss: 0.712744 d_acc:  0.74
# 88 85
# Generator Training  epoch:  1342 , d_loss: 1.05407 g_loss: 0.86869 d_acc:  0.865
# 66 27
# Discriminator Training  epoch:  1343 , d_loss: 1.35213 g_loss: 0.647457 d_acc:  0.465
# Generator Training  epoch:  1343 , d_loss: 1.35213 g_loss: 0.647457 d_acc:  0.465
# 41 100
# Discriminator Training  epoch:  1344 , d_loss: 1.16321 g_loss: 1.17598 d_acc:  0.705
# Generator Training  epoch:  1344 , d_loss: 1.16321 g_loss: 1.17598 d_acc:  0.705
# 82 98
# Generator Training  epoch:  1345 , d_loss: 1.0508 g_loss: 0.942403 d_acc:  0.9
# 77 65
# Discriminator Training  epoch:  1346 , d_loss: 1.2342 g_loss: 0.74046 d_acc:  0.71
# Generator Training  epoch:  1346 , d_loss: 1.2342 g_loss: 0.74046 d_acc:  0.71
# 73 96
# Generator Training  epoch:  1347 , d_loss: 1.11561 g_loss: 0.902726 d_acc:  0.845
# 63 63
# Discriminator Training  epoch:  1348 , d_loss: 1.31011 g_loss: 0.717273 d_acc:  0.63
# Generator Training  epoch:  1348 , d_loss: 1.31011 g_loss: 0.717273 d_acc:  0.63
# 67 99
# Generator Training  epoch:  1349 , d_loss: 1.12445 g_loss: 1.02592 d_acc:  0.83
# 43 78
# Discriminator Training  epoch:  1350 , d_loss: 1.37062 g_loss: 0.842111 d_acc:  0.605
# Generator Training  epoch:  1350 , d_loss: 1.37062 g_loss: 0.842111 d_acc:  0.605
# 69 91
# Generator Training  epoch:  1351 , d_loss: 1.16666 g_loss: 0.847089 d_acc:  0.8
# 72 35
# Discriminator Training  epoch:  1352 , d_loss: 1.36445 g_loss: 0.625094 d_acc:  0.535
# Generator Training  epoch:  1352 , d_loss: 1.36445 g_loss: 0.625094 d_acc:  0.535
# 48 71
# Discriminator Training  epoch:  1353 , d_loss: 1.30923 g_loss: 0.829671 d_acc:  0.595
# Generator Training  epoch:  1353 , d_loss: 1.30923 g_loss: 0.829671 d_acc:  0.595
# 45 83
# Discriminator Training  epoch:  1354 , d_loss: 1.27594 g_loss: 0.898162 d_acc:  0.64
# Generator Training  epoch:  1354 , d_loss: 1.27594 g_loss: 0.898162 d_acc:  0.64
# 80 47
# Discriminator Training  epoch:  1355 , d_loss: 1.23453 g_loss: 0.706786 d_acc:  0.635
# Generator Training  epoch:  1355 , d_loss: 1.23453 g_loss: 0.706786 d_acc:  0.635
# 81 93
# Generator Training  epoch:  1356 , d_loss: 1.07089 g_loss: 0.870713 d_acc:  0.87
# 84 26
# Discriminator Training  epoch:  1357 , d_loss: 1.23413 g_loss: 0.644461 d_acc:  0.55
# Generator Training  epoch:  1357 , d_loss: 1.23413 g_loss: 0.644461 d_acc:  0.55
# 44 100
# Discriminator Training  epoch:  1358 , d_loss: 1.2095 g_loss: 0.973135 d_acc:  0.72
# Generator Training  epoch:  1358 , d_loss: 1.2095 g_loss: 0.973135 d_acc:  0.72
# 70 71
# Discriminator Training  epoch:  1359 , d_loss: 1.23442 g_loss: 0.760661 d_acc:  0.705
# Generator Training  epoch:  1359 , d_loss: 1.23442 g_loss: 0.760661 d_acc:  0.705
# 52 49
# Discriminator Training  epoch:  1360 , d_loss: 1.402 g_loss: 0.701181 d_acc:  0.505
# Generator Training  epoch:  1360 , d_loss: 1.402 g_loss: 0.701181 d_acc:  0.505
# 53 76
# Discriminator Training  epoch:  1361 , d_loss: 1.35541 g_loss: 0.822275 d_acc:  0.645
# Generator Training  epoch:  1361 , d_loss: 1.35541 g_loss: 0.822275 d_acc:  0.645
# 61 63
# Discriminator Training  epoch:  1362 , d_loss: 1.35822 g_loss: 0.76259 d_acc:  0.62
# Generator Training  epoch:  1362 , d_loss: 1.35822 g_loss: 0.76259 d_acc:  0.62
# 54 61
# Discriminator Training  epoch:  1363 , d_loss: 1.34299 g_loss: 0.816966 d_acc:  0.575
# Generator Training  epoch:  1363 , d_loss: 1.34299 g_loss: 0.816966 d_acc:  0.575
# 67 67
# Discriminator Training  epoch:  1364 , d_loss: 1.2073 g_loss: 0.859258 d_acc:  0.67
# Generator Training  epoch:  1364 , d_loss: 1.2073 g_loss: 0.859258 d_acc:  0.67
# 54 84
# Discriminator Training  epoch:  1365 , d_loss: 1.19891 g_loss: 1.03749 d_acc:  0.69
# Generator Training  epoch:  1365 , d_loss: 1.19891 g_loss: 1.03749 d_acc:  0.69
# 61 72
# Discriminator Training  epoch:  1366 , d_loss: 1.23383 g_loss: 0.844762 d_acc:  0.665
# Generator Training  epoch:  1366 , d_loss: 1.23383 g_loss: 0.844762 d_acc:  0.665
# 72 95
# Generator Training  epoch:  1367 , d_loss: 1.12389 g_loss: 0.917024 d_acc:  0.835
# 74 33
# Discriminator Training  epoch:  1368 , d_loss: 1.3104 g_loss: 0.633131 d_acc:  0.535
# Generator Training  epoch:  1368 , d_loss: 1.3104 g_loss: 0.633131 d_acc:  0.535
# 32 100
# Discriminator Training  epoch:  1369 , d_loss: 1.23435 g_loss: 1.37312 d_acc:  0.66
# Generator Training  epoch:  1369 , d_loss: 1.23435 g_loss: 1.37312 d_acc:  0.66
# 77 69
# Discriminator Training  epoch:  1370 , d_loss: 1.12598 g_loss: 0.797954 d_acc:  0.73
# Generator Training  epoch:  1370 , d_loss: 1.12598 g_loss: 0.797954 d_acc:  0.73
# 84 64
# Discriminator Training  epoch:  1371 , d_loss: 1.13952 g_loss: 0.7712 d_acc:  0.74
# Generator Training  epoch:  1371 , d_loss: 1.13952 g_loss: 0.7712 d_acc:  0.74
# 59 100
# Discriminator Training  epoch:  1372 , d_loss: 1.07859 g_loss: 1.17879 d_acc:  0.795
# Generator Training  epoch:  1372 , d_loss: 1.07859 g_loss: 1.17879 d_acc:  0.795
# 79 87
# Generator Training  epoch:  1373 , d_loss: 1.11688 g_loss: 0.857174 d_acc:  0.83
# 81 1
# Discriminator Training  epoch:  1374 , d_loss: 1.49967 g_loss: 0.498438 d_acc:  0.41
# Generator Training  epoch:  1374 , d_loss: 1.49967 g_loss: 0.498438 d_acc:  0.41
# 27 98
# Discriminator Training  epoch:  1375 , d_loss: 1.28983 g_loss: 1.25825 d_acc:  0.625
# Generator Training  epoch:  1375 , d_loss: 1.28983 g_loss: 1.25825 d_acc:  0.625
# 72 87
# Discriminator Training  epoch:  1376 , d_loss: 1.03822 g_loss: 1.02122 d_acc:  0.795
# Generator Training  epoch:  1376 , d_loss: 1.03822 g_loss: 1.02122 d_acc:  0.795
# 96 90
# Generator Training  epoch:  1377 , d_loss: 0.863901 g_loss: 0.89854 d_acc:  0.93
# 98 55
# Discriminator Training  epoch:  1378 , d_loss: 1.03723 g_loss: 0.690505 d_acc:  0.765
# Generator Training  epoch:  1378 , d_loss: 1.03723 g_loss: 0.690505 d_acc:  0.765
# 88 100
# Generator Training  epoch:  1379 , d_loss: 0.791825 g_loss: 1.26893 d_acc:  0.94
# 80 90
# Generator Training  epoch:  1380 , d_loss: 0.981416 g_loss: 0.922647 d_acc:  0.85
# 76 48
# Discriminator Training  epoch:  1381 , d_loss: 1.21867 g_loss: 0.686995 d_acc:  0.62
# Generator Training  epoch:  1381 , d_loss: 1.21867 g_loss: 0.686995 d_acc:  0.62
# 48 100
# Discriminator Training  epoch:  1382 , d_loss: 1.07206 g_loss: 1.45494 d_acc:  0.74
# Generator Training  epoch:  1382 , d_loss: 1.07206 g_loss: 1.45494 d_acc:  0.74
# 91 100
# Generator Training  epoch:  1383 , d_loss: 0.835079 g_loss: 1.02864 d_acc:  0.955
# 87 49
# Discriminator Training  epoch:  1384 , d_loss: 1.1198 g_loss: 0.684543 d_acc:  0.68
# Generator Training  epoch:  1384 , d_loss: 1.1198 g_loss: 0.684543 d_acc:  0.68
# 83 75
# Discriminator Training  epoch:  1385 , d_loss: 1.06079 g_loss: 0.876178 d_acc:  0.79
# Generator Training  epoch:  1385 , d_loss: 1.06079 g_loss: 0.876178 d_acc:  0.79
# 57 85
# Discriminator Training  epoch:  1386 , d_loss: 1.17274 g_loss: 1.12406 d_acc:  0.71
# Generator Training  epoch:  1386 , d_loss: 1.17274 g_loss: 1.12406 d_acc:  0.71
# 82 67
# Discriminator Training  epoch:  1387 , d_loss: 1.05609 g_loss: 0.872042 d_acc:  0.745
# Generator Training  epoch:  1387 , d_loss: 1.05609 g_loss: 0.872042 d_acc:  0.745
# 76 99
# Generator Training  epoch:  1388 , d_loss: 0.980166 g_loss: 1.03997 d_acc:  0.875
# 74 88
# Generator Training  epoch:  1389 , d_loss: 1.13812 g_loss: 0.828118 d_acc:  0.81
# 71 13
# Discriminator Training  epoch:  1390 , d_loss: 1.42476 g_loss: 0.58605 d_acc:  0.42
# Generator Training  epoch:  1390 , d_loss: 1.42476 g_loss: 0.58605 d_acc:  0.42
# 34 100
# Discriminator Training  epoch:  1391 , d_loss: 1.20341 g_loss: 1.36196 d_acc:  0.67
# Generator Training  epoch:  1391 , d_loss: 1.20341 g_loss: 1.36196 d_acc:  0.67
# 83 79
# Generator Training  epoch:  1392 , d_loss: 0.998753 g_loss: 0.991162 d_acc:  0.81
# 75 36
# Discriminator Training  epoch:  1393 , d_loss: 1.30133 g_loss: 0.7004 d_acc:  0.555
# Generator Training  epoch:  1393 , d_loss: 1.30133 g_loss: 0.7004 d_acc:  0.555
# 76 84
# Generator Training  epoch:  1394 , d_loss: 1.1358 g_loss: 0.871878 d_acc:  0.8
# 72 31
# Discriminator Training  epoch:  1395 , d_loss: 1.37802 g_loss: 0.653297 d_acc:  0.515
# Generator Training  epoch:  1395 , d_loss: 1.37802 g_loss: 0.653297 d_acc:  0.515
# 47 100
# Discriminator Training  epoch:  1396 , d_loss: 1.17351 g_loss: 1.14702 d_acc:  0.735
# Generator Training  epoch:  1396 , d_loss: 1.17351 g_loss: 1.14702 d_acc:  0.735
# 66 94
# Generator Training  epoch:  1397 , d_loss: 1.07033 g_loss: 1.00274 d_acc:  0.8
# 76 55
# Discriminator Training  epoch:  1398 , d_loss: 1.19104 g_loss: 0.774151 d_acc:  0.655
# Generator Training  epoch:  1398 , d_loss: 1.19104 g_loss: 0.774151 d_acc:  0.655
# 72 74
# Discriminator Training  epoch:  1399 , d_loss: 1.15496 g_loss: 0.899382 d_acc:  0.73
# Generator Training  epoch:  1399 , d_loss: 1.15496 g_loss: 0.899382 d_acc:  0.73
# 50 86
# Discriminator Training  epoch:  1400 , d_loss: 1.19708 g_loss: 0.998587 d_acc:  0.68
# Generator Training  epoch:  1400 , d_loss: 1.19708 g_loss: 0.998587 d_acc:  0.68
# 91 75
# Generator Training  epoch:  1401 , d_loss: 1.05311 g_loss: 0.825848 d_acc:  0.83
# 69 47
# Discriminator Training  epoch:  1402 , d_loss: 1.38763 g_loss: 0.625211 d_acc:  0.58
# Generator Training  epoch:  1402 , d_loss: 1.38763 g_loss: 0.625211 d_acc:  0.58
# 65 71
# Discriminator Training  epoch:  1403 , d_loss: 1.18452 g_loss: 0.845816 d_acc:  0.68
# Generator Training  epoch:  1403 , d_loss: 1.18452 g_loss: 0.845816 d_acc:  0.68
# 64 97
# Generator Training  epoch:  1404 , d_loss: 1.12336 g_loss: 0.963774 d_acc:  0.805
# 61 48
# Discriminator Training  epoch:  1405 , d_loss: 1.39588 g_loss: 0.676978 d_acc:  0.545
# Generator Training  epoch:  1405 , d_loss: 1.39588 g_loss: 0.676978 d_acc:  0.545
# 68 88
# Discriminator Training  epoch:  1406 , d_loss: 1.1367 g_loss: 0.885793 d_acc:  0.78
# Generator Training  epoch:  1406 , d_loss: 1.1367 g_loss: 0.885793 d_acc:  0.78
# 84 94
# Generator Training  epoch:  1407 , d_loss: 0.9988 g_loss: 0.965427 d_acc:  0.89
# 68 53
# Discriminator Training  epoch:  1408 , d_loss: 1.30686 g_loss: 0.710134 d_acc:  0.605
# Generator Training  epoch:  1408 , d_loss: 1.30686 g_loss: 0.710134 d_acc:  0.605
# 68 91
# Discriminator Training  epoch:  1409 , d_loss: 1.1335 g_loss: 0.932455 d_acc:  0.795
# Generator Training  epoch:  1409 , d_loss: 1.1335 g_loss: 0.932455 d_acc:  0.795
# 75 94
# Generator Training  epoch:  1410 , d_loss: 1.09471 g_loss: 0.955741 d_acc:  0.845
